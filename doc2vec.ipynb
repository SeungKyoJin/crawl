# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import pickle
import os

# %%
from konlpy.tag import Komoran
from konlpy.tag import Twitter

# %%
client = MongoClient()
db = client.test
results = db.results

# %%
df_news = pd.DataFrame(list(results.find({}, {'title' : 'true', 'contents' : 'true', 'keywords' : 'true'})))

# %%
df_news.to_pickle("./df_news.pkl")

# %%
df_news = pd.read_pickle('./df_news.pkl')

# %%
df = df_news.iloc[:, 1:]

# %%
df
# Out:
#                                                contents keywords  \
# 0     동영상 뉴스\n■ 김은경 / 환경부 장관\n\n[앵커]\n얼마 전까지만 해도 우리나...       홍수
# 1     [한국경제TV 이근형 기자]\n지방 아파트 입주가 크게 늘면서 기존 전월세 임대인들...       홍수
# 2     선거홍보문자 관련 개인정보 침해상담 급증…한 달 간 상담 1만건 넘어\n개인정보 출...       홍수
# 3     "안녕하십니까. 이번 지방선거에 출마한 △△당 후보 ○○○입니다."\n6·13 지방...       홍수
# 4     미얀마 정부군의 탄압을 피해 국경을 넘어 방글라데시로 탈출한 이슬람계 소수민족 로힝...       홍수
# 5     난민 캠프 가건물 300채 파손…세 살배기, 흙더미에 깔려 숨져\n\n유엔 기구 "...       홍수
# 6     넥슨(대표 이정헌)의 신작 모바일 MMORPG ‘카이저(KAISER)’가 구글 플레...       홍수
# 7     조민희 로켓펀치 대표 (사진=신태현 기자)\n[이데일리 이재길 기자] “디지털 기술...       홍수
# 8     여주시장 선거에 출마한 이충우 한국당 후보의 답변... "주변 개발해 편의시설 만들...       홍수
# 9     6·13 지방선거에 출마한 대구경북 후보자들의 온갖 공약이 쏟아지고 있다. 저마다 ...       홍수
# 10    [한겨레] 염형철\n물개혁포럼 공동대표\n\n지난 90년 동안 수도권에서 발생한 가...       홍수
# 11    강물 범람으로 홍수가 난 쿠바의 한 마을 [AFP=연합뉴스]\n\n\n(멕시코시티=...       홍수
# 12    쿠바에서 최근 아열대성 폭풍으로 인해 홍수가 나는 바람에 7명이 숨지고 2명이 실종...       홍수
# 13    쿠바에서 최근 아열대성 폭풍으로 인해 홍수가 나는 바람에 7명이 숨지고 2명이 실종...       홍수
# 14    [서울경제] 쿠바에서 홍수가 발생해 7명이 숨지고 2명이 실종됐다고 공산당 기관지 ...       홍수
# 15    빠듯한 선거운동 일정 속 기관‧단체 정책질의 쏟아져\n편향 정책질의라도 답변 거부 ...       홍수
# 16    [동아일보]\n◇보건복지부 △기초의료보장과장 임은정 △질병관리본부 생명과학연구관리과...       홍수
# 17    (속초=연합뉴스) 6·13 지방선거 선거운동이 본격적으로 시작되면서 유권자들에게 발...       홍수
# 18    (속초=연합뉴스) 6·13 지방선거 선거운동이 본격적으로 시작되면서 유권자들에게 발...       홍수
# 19    조직개편후 홍수대비 급선무\n\n물관리일원화를 담은 정부조직법 개정안이 국무회의에서...       홍수
# 20    정부의 물관리 일원화 방침에 따라 국토교통부에서 환경부로 188명의 인력과 약 6천...       홍수
# 21    대전과 청주 사이 금강을 가로지르는 대청댐. 정부조직법 개정으로 수질뿐만 아니라 수...       홍수
# 22    수량·수질·재해예방 등 물관리 관련 법령 국무회의서 심의·의결\n\n국무회의 모습(...       홍수
# 23    물관리일원화 정부조직법 개정\n국토부서 188명·예산 6000억 이관\n국가·유역단...       홍수
# 24    현충일 앞두고 대전현충원 소방공무원 묘역 추모 발길\n\n강릉 석란정 순직 소방관 ...       홍수
# 25    MBC 시사프로그램 ‘PD수첩’이 15일 부영그룹의 공공 임대 아파트인 ‘사랑으로’...       홍수
# 26    동영상 뉴스\n[뉴스투데이]◀ 앵커 ▶\n\n미국 하와이 카우아이 섬에 하루 사이 ...       홍수
# 27    미국 하와이 주도 호놀룰루가 있는 오아후 섬 북서부 카우아이 섬에 홍수와 산사태가 ...       홍수
# 28    [한국경제TV 김현경 기자]\n\n\n미국 하와이에서 대규모 홍수 사태가 발생했다....       홍수
# 29    (로스앤젤레스=연합뉴스) 옥철 특파원 = 미국 하와이 주도 호놀룰루가 있는 오아후 ...       홍수
# ...                                                 ...      ...
# 7841  © News1\n\n(서울=뉴스1) 박정양 기자 = 제18호 태풍 '탈림'이 우리나...       태풍
# 7842  [머니투데이 이미호 기자] [조종묵 소방청장, 조기 상황판단회의 개최 ]\n\n조종...       태풍
# 7843  【서울=뉴시스】 지난 17일 오전 일본 남부 규슈(九州) 지방에 상륙한 제 18호 ...       태풍
# 7844  2017.9.14/뉴스1 © News1 임준현 인턴기자\n\n아침 최저 12~20도...       태풍
# 7845  【서울=뉴시스】고범준 기자 = 2일 오후 서울 동작구 기상청 국가기상센터에서 정관영...       태풍
# 7846  <앵커 멘트>\n\n초대형 태풍 '란'이 일본 열도를 강타하면서 인명 피해가 속출했...       태풍
# 7847  제23호 태풍 담레이가 베트남 중상부에 상륙한 가운데 태풍으로 인한 사망자수는 61...       태풍
# 7848  동영상 뉴스\n[뉴스투데이]어제 일본 가고시마현에 상륙한 18호 태풍 '탈림'이 일...       태풍
# 7849  【강릉=뉴시스】김경목 기자 = 16일 오후 제18호 태풍 '탈림(TALIM)'의 북...       태풍
# 7850  하승철 경남도 재난안전대책본부장(맨왼쪽)이 14일 도청에서 열린 태풍 대비 상황판단...       태풍
# 7851  맑은 하늘 아래 추억 남기기[연합뉴스 자료사진]\n\n\n(서울=연합뉴스) 성서호 ...       태풍
# 7852  [머니투데이 유희석 기자]\n제13호 태풍 '하토'(HATO)가 강타한 마카오 거리...       태풍
# 7853  동영상 뉴스\n제13호 태풍 '하토'가 오늘(23일) 홍콩과 마카오를 강타하면서 5...       태풍
# 7854  제13호 태풍 '하토'가 오늘(23일) 홍콩과 마카오를 강타하면서 5명이 사망하거나...       태풍
# 7855  [이미지출처=AP연합뉴스]\n\n[아시아경제 조슬기나 기자] 일본을 강타한 21호 ...       태풍
# 7856  [그래픽] 제18호 태풍 '탈림' 영향…제주 오후에 비\n\n\n16일까지 최고 1...       태풍
# 7857  도로공사 "오후 11시 돼야 정체 해소될 듯"\n\n가을 하늘 반기는 코스모스(구리...       태풍
# 7858  도로공사 "서울 방향 고속도로 정체 오후 7∼8시께 해소"\n\n가을 하늘 반기는 ...       태풍
# 7859  오늘 전국이 대체로 맑은 가운데 일교차가 큰 날씨가 이어지고 있습니다.\n\n내일 ...       태풍
# 7860  오늘 전국이 대체로 맑은 가운데 일교차가 큰 날씨가 이어지고 있습니다.\n\n내일 ...       태풍
# 7861  제18호 태풍 ‘탈림’ (사진=기상청)\n[이데일리 e뉴스 김민정 기자] 제18호 ...       태풍
# 7862  【대구=뉴시스】박준 기자 = 대구시 수성구청 전경. 2018.06.03(사진=뉴시스...       태풍
# 7863  제18호 태풍 ‘탈림’ (사진=기상청)\n[이데일리 e뉴스 김민정 기자] 제18호 ...       태풍
# 7864  【대구=뉴시스】박준 기자 = 대구시 수성구청 전경. 2018.06.03(사진=뉴시스...       태풍
# 7865  일본 열도가 18호 태풍 '탈림'의 상륙으로 수많은 사상자가 발생하고 있다.\n\n...       태풍
# 7866  [헤럴드경제=이슈섹션] 제 18호 태풍 탈림이 당초 예측과 달리 일본으로 방향을 튼...       태풍
# 7867  [서울경제] 태풍 ‘탈림’과 ‘독수리’에 이목이 쏠리고 있다.\n\n대만을 향하다가...       태풍
# 7868  [헤럴드경제=이슈섹션] 주말인 21일은 전국이 대체로 맑고 쾌청한 가을 날씨가 될 ...       태풍
# 7869  서울 롯데월드타워 전망대 [연합뉴스 자료사진]\n\n\n(서울=연합뉴스) 안홍석 기...       태풍
# 7870  동영상 뉴스\n[날씨] 전형적인 가을 날씨…오후부터 제주 태풍 영향\n\n[앵커]\...       태풍
#
#                                               title
# 0                          물관리 업무 일원화 첫걸음...달라지는 점은
# 1                            지방 입주 홍수에 세입자 구하기 '비상'
# 2                '내 정보 어디서 샜을까'…'선거 홍보문자' 홍수에 민원 급증
# 3           6·13 지방선거 후보자 홍보 문자 홍수에 '개인정보 침해' 민원 급증
# 4           로힝야족 난민촌에 찾아온 우기... 산사태, 홍수 위기에 그대로 노출돼
# 5           방글라데시 수용 로힝야족 난민 90만명, 우기 맞아 '전전긍긍'(종합)
# 6           ‘카이저’, IP 홍수 속 오리지널리티 뽐냈다…구글 게임매출 5위 올라
# 7            [ESF2018]조민희 대표 "데이터 홍수 속 '진주 찾기'가 핵심"
# 8                   이충우 "4대강은 잘 된 사업, 가뭄·홍수 대비에 도움"
# 9                 [사설] 선거공약 홍수, 좋으면 골라 당선자가 적극 활용하자
# 10               [왜냐면] 팔당호 수위 낮춰 수도권 대홍수 대비하자 / 염형철
# 11                  쿠바서 홍수로 7명 사망·2명 실종…5만1천명 긴급 대피
# 12                  쿠바서 홍수로 7명 사망·2명 실종…5만1천명 긴급 대피
# 13                쿠바서 홍수로 7명 사망·2명 실종...5만1천명 긴급 대피
# 14                  쿠바 홍수로 5만1천명 긴급 대피..7명 남성 모두 사망
# 15                   정책질의 홍수 속 지선 단체장 후보들 남모를 ‘속앓이’
# 16                                      [인사]보건복지부 外
# 17                                        선거 우편물 홍수
# 18                                        선거 우편물 홍수
# 19                 물관리일원화 관련법령 의결… 국토부 5000명 환경부 이관
# 20                물 관리 일원화 따라 국토부서 환경부로 188명·6천억 이관
# 21                  물관리 일원화…국토부 수자원국, 수자원공사 환경부로 이관
# 22                 물관리 일원화 따라 국토부서 환경부로 188명·6천억 이관
# 23                            통합물관리 8일부터…예산·인력 환경부로
# 24                    화마·홍수 맞서다 순직…소방영웅 128명 이곳에 있다
# 25         “분뇨 역류하고 옥상 홍수” 부영그룹 부실시공… 최순실 관계는? (영상)
# 26                       하와이 홍수·산사태…주민 2백여 명 필사의 탈출
# 27                   하와이 대형 홍수…주민 200여 명 헬기로 필사의 탈출
# 28                           하와이 홍수, "단 몇 분 만에 잠겼다"
# 29                     하와이 홍수, 헬기로 주민 200여 명 필사의 구조
# ...                                             ...
# 7841                   태풍 '탈림' 영향 예상…소방청, 비상근무태세 점검
# 7842                태풍 '탈림' 빠르게 북상…소방청 "비상근무 태세 점검"
# 7843                               태풍 '탈림' 일본 열도 강타
# 7844                    [오늘 날씨] 태풍 영향권 벗어나 맑음…일교차 커
# 7845                               태풍 노루 주말 제주권에 영향
# 7846                  [글로벌 브리핑] 태풍 日 열도 관통…인명 피해 속출
# 7847                  태풍 `담레이` 베트남 상륙…사망자 61명으로 늘어나
# 7848                      태풍 '탈림' 日 강타…주민 78만 명 대피령
# 7849                   태풍 탈림 북상…동해중부 앞바다 풍랑주의보 발효 중
# 7850                  16일 영향권…경남도 18호 태풍 ‘탈림’ 대응 분주
# 7851               [내일날씨] 대체로 '맑음'…태풍에 제주 최대 150㎜ 비
# 7852             태풍 '하토'에 마카오 초토화…3명 사망, 전력·수도 문제까지
# 7853                       홍콩·마카오 태풍 강타... 5명 사망·실종
# 7854                       홍콩·마카오 태풍 강타... 5명 사망·실종
# 7855                   '태풍 란' 日 강타…최소 5명 사망·132명 다쳐
# 7856                   제주도 육·해상 태풍 예비특보…대응태세 돌입(종합)
# 7857              태풍 지나고 화창한 휴일…나들이·벌초객으로 곳곳 정체(종합)
# 7858                 태풍 지나고 화창한 휴일…나들이·벌초객으로 도로 북새통
# 7859                         큰 일교차 주의…모레 제주도 태풍 영향권
# 7860                         큰 일교차 주의…모레 제주도 태풍 영향권
# 7861                   日 열도, 태풍 탈림 강타에 `비상`…40여명 사상
# 7862              "폭염 등 걱정마세요" 수성구, 자연재난 종합대책 마련 추진
# 7863                   日 열도, 태풍 탈림 강타에 `비상`…40여명 사상
# 7864              "폭염 등 걱정마세요" 수성구, 자연재난 종합대책 마련 추진
# 7865                日 18호 태풍 `탈림` 상륙에 2명 사망·3명 행방불명
# 7866                 태풍 ‘탈림’ 이어 ‘독수리’까지…쌍태풍 사태 ‘긴장’
# 7867  태풍 독수리는 또 뭐야? 쌍 태풍에 커지는 불안감↑ “시속 22km로 서북 서진”
# 7868                    쾌청한 주말…제주도 태풍 ‘란’ 영향권 강한 바람
# 7869                  [내일날씨] 태풍 지나고 전국 맑은 가운데 큰 일교차
# 7870                  [날씨] 전형적인 가을 날씨…오후부터 제주 태풍 영향
#
# [7871 rows x 3 columns]

# %%
twitter = Twitter()
def tokenizer_twitter_morphs(doc):
    return twitter.morphs(doc)

def tokenizer_twitter_noun(doc):
    return twitter.nouns(doc)

def tokenizer_twitter_pos(doc):
    return twitter.pos(doc, norm=True, stem=True)
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
komoran = Komoran()
def tokenizer_noun(doc):
    return komoran.nouns(doc)

def tokenizer_morphs(doc):
    return komoran.porphs(doc)

# %%
df_news['token_title'] = df_news['title'].apply(tokenizer_twitter_morphs)

# %%
df_news['token_contents'] = df_news['contents'].apply(tokenizer_twitter_morphs)

# %%
df_news['token_keywords'] = df_news['keywords'].apply(tokenizer_twitter_morphs)

# %%
df_news.head()
# Out:
#                         _id  \
# 0  5cb32a7085861022e66585f2
# 1  5cb32a7285861022e66585f3
# 2  5cb32a7485861022e66585f4
# 3  5cb32a7585861022e66585f5
# 4  5cb32a7885861022e66585f6
#
#                                             contents keywords  \
# 0  동영상 뉴스\n■ 김은경 / 환경부 장관\n\n[앵커]\n얼마 전까지만 해도 우리나...       홍수
# 1  [한국경제TV 이근형 기자]\n지방 아파트 입주가 크게 늘면서 기존 전월세 임대인들...       홍수
# 2  선거홍보문자 관련 개인정보 침해상담 급증…한 달 간 상담 1만건 넘어\n개인정보 출...       홍수
# 3  "안녕하십니까. 이번 지방선거에 출마한 △△당 후보 ○○○입니다."\n6·13 지방...       홍수
# 4  미얀마 정부군의 탄압을 피해 국경을 넘어 방글라데시로 탈출한 이슬람계 소수민족 로힝...       홍수
#
#                                      title  \
# 0                 물관리 업무 일원화 첫걸음...달라지는 점은
# 1                   지방 입주 홍수에 세입자 구하기 '비상'
# 2       '내 정보 어디서 샜을까'…'선거 홍보문자' 홍수에 민원 급증
# 3  6·13 지방선거 후보자 홍보 문자 홍수에 '개인정보 침해' 민원 급증
# 4  로힝야족 난민촌에 찾아온 우기... 산사태, 홍수 위기에 그대로 노출돼
#
#                                          token_title  \
# 0             [물, 관리, 업무, 일원화, 첫걸음, ..., 달라지는, 점, 은]
# 1            [지방, 입주, 홍수, 에, 세, 입자, 구, 하기, ', 비상, ']
# 2  [', 내, 정보, 어디서, 샜을까, '…', 선거, 홍보, 문자, ', 홍수, 에...
# 3  [6, ·, 13, 지방선거, 후보자, 홍보, 문자, 홍수, 에, ', 개인정보, ...
# 4  [로힝야족, 난민, 촌, 에, 찾아온, 우기, ..., 산사태, ,, 홍수, 위기,...
#
#                                       token_contents token_keywords
# 0  [동영상, 뉴스, \n, ■, 김은경, /, 환경부, 장관, \n\n, [, 앵커,...           [홍수]
# 1  [[, 한국, 경제, TV, 이근형, 기자, ], \n, 지방, 아파트, 입, 주가...           [홍수]
# 2  [선거, 홍보, 문자, 관련, 개인정보, 침해, 상담, 급증, …, 한, 달, 간,...           [홍수]
# 3  [", 안녕하십니까, ., 이번, 지방선거, 에, 출마, 한, △△, 당, 후보, ...           [홍수]
# 4  [미얀마, 정부, 군, 의, 탄압, 을, 피해, 국경, 을, 넘어, 방글라데시, 로...           [홍수]

# %%
tokens_title = [t for d in df_news['token_title'] for t in d]
tokens_contents = [t for d in df_news['token_contents'] for t in d]
tokens_keywords = [t for d in df_news['token_keywords'] for t in d]

# %%
tokens_title
# Out:
# ['물',
#  '관리',
#  '업무',
#  '일원화',
#  '첫걸음',
#  '...',
#  '달라지는',
#  '점',
#  '은',
#  '지방',
#  '입주',
#  '홍수',
#  '에',
#  '세',
#  '입자',
#  '구',
#  '하기',
#  "'",
#  '비상',
#  "'",
#  "'",
#  '내',
#  '정보',
#  '어디서',
#  '샜을까',
#  "'…'",
#  '선거',
#  '홍보',
#  '문자',
#  "'",
#  '홍수',
#  '에',
#  '민원',
#  '급증',
#  '6',
#  '·',
#  '13',
#  '지방선거',
#  '후보자',
#  '홍보',
#  '문자',
#  '홍수',
#  '에',
#  "'",
#  '개인정보',
#  '침해',
#  "'",
#  '민원',
#  '급증',
#  '로힝야족',
#  '난민',
#  '촌',
#  '에',
#  '찾아온',
#  '우기',
#  '...',
#  '산사태',
#  ',',
#  '홍수',
#  '위기',
#  '에',
#  '그대로',
#  '노출',
#  '돼',
#  '방글라데시',
#  '수용',
#  '로힝야족',
#  '난민',
#  '90만',
#  '명',
#  ',',
#  '우기',
#  '맞아',
#  "'",
#  '전전긍긍',
#  "'(",
#  '종합',
#  ')',
#  '‘',
#  '카이저',
#  '’,',
#  'IP',
#  '홍수',
#  '속',
#  '오',
#  '리지',
#  '널리',
#  '티',
#  '뽐냈다',
#  '…',
#  '구글',
#  '게임',
#  '매출',
#  '5',
#  '위',
#  '올라',
#  '[',
#  'ESF',
#  '2018',
#  ']',
#  '조민희',
#  '대표',
#  '"',
#  '데이터',
#  '홍수',
#  '속',
#  "'",
#  '진주',
#  '찾기',
#  "'",
#  '가',
#  '핵심',
#  '"',
#  '이충',
#  '우',
#  '"',
#  '4',
#  '대강',
#  '은',
#  '잘',
#  '된',
#  '사업',
#  ',',
#  '가뭄',
#  '·',
#  '홍수',
#  '대비',
#  '에',
#  '도움',
#  '"',
#  '[',
#  '사설',
#  ']',
#  '선거',
#  '공약',
#  '홍수',
#  ',',
#  '좋으면',
#  '골라',
#  '당선자',
#  '가',
#  '적극',
#  '활용',
#  '하자',
#  '[',
#  '왜냐면',
#  ']',
#  '팔당호',
#  '수위',
#  '낮춰',
#  '수도권',
#  '대홍수',
#  '대비',
#  '하자',
#  '/',
#  '염',
#  '형',
#  '철',
#  '쿠바',
#  '서',
#  '홍수',
#  '로',
#  '7',
#  '명',
#  '사망',
#  '·',
#  '2',
#  '명',
#  '실종',
#  '…',
#  '5만',
#  '1천',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '서',
#  '홍수',
#  '로',
#  '7',
#  '명',
#  '사망',
#  '·',
#  '2',
#  '명',
#  '실종',
#  '…',
#  '5만',
#  '1천',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '서',
#  '홍수',
#  '로',
#  '7',
#  '명',
#  '사망',
#  '·',
#  '2',
#  '명',
#  '실종',
#  '...',
#  '5만',
#  '1천',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '로',
#  '5만',
#  '1천',
#  '명',
#  '긴급',
#  '대피',
#  '..',
#  '7',
#  '명',
#  '남성',
#  '모두',
#  '사망',
#  '정책',
#  '질의',
#  '홍수',
#  '속',
#  '지선',
#  '단체',
#  '장',
#  '후보',
#  '들',
#  '남모를',
#  '‘',
#  '속',
#  '앓이',
#  '’',
#  '[',
#  '인사',
#  ']',
#  '보건복지부',
#  '外',
#  '선거',
#  '우편물',
#  '홍수',
#  '선거',
#  '우편물',
#  '홍수',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '…',
#  '국토부',
#  '5000',
#  '명',
#  '환경부',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '…',
#  '국토부',
#  '수자원',
#  '국',
#  ',',
#  '수자원공사',
#  '환경부',
#  '로',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '8일',
#  '부터',
#  '…',
#  '예산',
#  '·',
#  '인력',
#  '환경부',
#  '로',
#  '화마',
#  '·',
#  '홍수',
#  '맞서다',
#  '순직',
#  '…',
#  '소',
#  '방영웅',
#  '128',
#  '명',
#  '이',
#  '곳',
#  '에',
#  '있다',
#  '“',
#  '분뇨',
#  '역류',
#  '하고',
#  '옥상',
#  '홍수',
#  '”',
#  '부영',
#  '그룹',
#  '부실',
#  '시공',
#  '…',
#  '최',
#  '순',
#  '실',
#  '관계',
#  '는',
#  '?',
#  '(',
#  '영상',
#  ')',
#  '하와이',
#  '홍수',
#  '·',
#  '산사태',
#  '…',
#  '주민',
#  '2',
#  '백여',
#  '명',
#  '필사',
#  '의',
#  '탈출',
#  '하와이',
#  '대형',
#  '홍수',
#  '…',
#  '주민',
#  '200',
#  '여',
#  '명',
#  '헬기',
#  '로',
#  '필사',
#  '의',
#  '탈출',
#  '하와이',
#  '홍수',
#  ',',
#  '"',
#  '단',
#  '몇',
#  '분',
#  '만에',
#  '잠겼다',
#  '"',
#  '하와이',
#  '홍수',
#  ',',
#  '헬기',
#  '로',
#  '주민',
#  '200',
#  '여',
#  '명',
#  '필사',
#  '의',
#  '구조',
#  '하와이',
#  '홍수',
#  ',',
#  '헬기',
#  '로',
#  '주민',
#  '200',
#  '여',
#  '명',
#  '필사',
#  '의',
#  '구조',
#  '후보',
#  '59',
#  '명',
#  '중',
#  '49',
#  '명',
#  '이',
#  '…',
#  '교육감',
#  '선거',
#  '‘',
#  '무상',
#  '공약',
#  '’',
#  '홍수',
#  '신제품',
#  '맥주',
#  '국산',
#  "'",
#  '실종',
#  "'",
#  '외산',
#  "'",
#  '홍수',
#  "'…",
#  '생산',
#  '기반',
#  '흔들리나',
#  '통일부',
#  '"',
#  '北',
#  '산림',
#  '32%',
#  '황폐',
#  '화',
#  '...',
#  '홍수',
#  '로',
#  '피해',
#  '가중',
#  '"',
#  '통일부',
#  '"',
#  '北',
#  '산림',
#  '32%',
#  '황폐',
#  '화',
#  '…',
#  '홍수',
#  '·',
#  '산사태',
#  '피해',
#  '가중',
#  '"',
#  '통일부',
#  '"',
#  '北',
#  '산림',
#  '32%',
#  '가',
#  '황폐',
#  '화',
#  '…',
#  '홍수',
#  '등',
#  '으로',
#  '피해',
#  '가중',
#  '"',
#  '통일부',
#  '"',
#  '北',
#  '산림',
#  '32%',
#  '가',
#  '황폐',
#  '화',
#  '…',
#  '홍수',
#  '등',
#  '으로',
#  '피해',
#  '가중',
#  '"',
#  '獨',
#  ',',
#  '홍수',
#  '로',
#  '탈출',
#  '한',
#  '맹수',
#  '들',
#  '생포',
#  '[',
#  '사설',
#  ']',
#  '포퓰리즘',
#  '공약',
#  '홍수',
#  '…',
#  '아이',
#  '들',
#  '미래',
#  '맡길',
#  '교육감',
#  '가려내야',
#  '[',
#  '분단',
#  '장벽',
#  '헐',
#  '린다',
#  ']',
#  '②',
#  '민족',
#  '의',
#  '젖줄',
#  '임진강',
#  "'",
#  '남북',
#  '교류',
#  '의',
#  '장',
#  '으로',
#  "'",
#  '뉴욕',
#  '은',
#  '지금',
#  '가상',
#  '화폐',
#  '컨퍼런스',
#  '홍수',
#  '[',
#  '고',
#  '현장',
#  ']',
#  '美',
#  '메릴랜드주',
#  '덮',
#  '친',
#  '홍수',
#  '…',
#  '마을',
#  '은',
#  '‘',
#  '쑥대밭',
#  '’',
#  '통일부',
#  '"',
#  '북한',
#  '산림',
#  '32%',
#  '황폐',
#  '화',
#  '…',
#  '홍수',
#  'ㆍ',
#  '산사태',
#  '유발',
#  '"',
#  '[',
#  '북한',
#  '단신',
#  ']',
#  '김영남',
#  ',',
#  '케냐',
#  '대통령',
#  '에',
#  '홍수',
#  '피해',
#  '위로',
#  '[',
#  '이',
#  '시각',
#  '세계',
#  ']',
#  '홍수',
#  '나자',
#  '동물원',
#  '맹수',
#  '들',
#  '집단',
#  '탈주',
#  '알베르토',
#  '강타',
#  '미',
#  '동',
#  '부지역',
#  ',',
#  '홍수',
#  '로',
#  '사망',
#  '5',
#  '명',
#  '실종자',
#  '다수',
#  '미',
#  '메릴랜드주',
#  '홍수',
#  '로',
#  '비상',
#  '사태',
#  '선포',
#  '…',
#  '지구촌',
#  '물난리',
#  '미',
#  '동부',
#  '메릴랜드',
#  '주',
#  ',',
#  '갑작스러운',
#  '폭우',
#  '로',
#  '홍수',
#  '…',
#  '‘',
#  '비상',
#  '사태',
#  '’',
#  '선포',
#  '[',
#  '영상',
#  ']',
#  '美',
#  '메릴랜드',
#  ',',
#  '기록',
#  '적',
#  '폭우',
#  '로',
#  '홍수',
#  '로',
#  "'",
#  '비상',
#  '사태',
#  "'",
#  '선포',
#  '美',
#  '메릴랜드주',
#  '홍수',
#  '美',
#  '메릴랜드주',
#  '홍수',
#  '로',
#  '1',
#  '명',
#  '실종',
#  '…',
#  '공군',
#  '출신',
#  '주',
#  '방위',
#  '군',
#  '이스라엘',
#  '사해',
#  '근처',
#  '서',
#  '홍수',
#  '로',
#  '청소년',
#  '9',
#  '명',
#  '사망',
#  '·',
#  '1',
#  '명',
#  '실종',
#  '이스라엘',
#  '사해',
#  '근처',
#  '서',
#  '홍수',
#  '로',
#  '청소년',
#  '9',
#  '명',
#  '사망',
#  '·',
#  '1',
#  '명',
#  '실종',
#  '이스라엘',
#  '사해',
#  '근처',
#  '서',
#  '홍수',
#  '로',
#  '청소년',
#  '9',
#  '명',
#  '사망',
#  '·',
#  '1',
#  '명',
#  '실종',
#  '울릉도',
#  '빗물',
#  '저장',
#  '시설',
#  '건립',
#  '…',
#  '홍수',
#  '막고',
#  '농업',
#  '용수로',
#  '활용',
#  '거리',
#  '곳곳',
#  '불법',
#  '광고',
#  '물',
#  '홍수',
#  '…',
#  '김포시',
#  "'",
#  '현수막',
#  '과의',
#  '전쟁',
#  '선포',
#  "'",
#  '미국',
#  '메릴랜드주',
#  ',',
#  '홍수',
#  '로',
#  '비상',
#  '사태',
#  '선포',
#  '[',
#  '신',
#  'TOEIC',
#  '만점',
#  '비법',
#  ']',
#  '홍수',
#  '피해',
#  '분양',
#  '홍수',
#  '·',
#  '청약',
#  '쏠림',
#  '·',
#  '거래',
#  '절벽',
#  '…',
#  '부동산',
#  '시장',
#  '‘',
#  '3',
#  '重',
#  '악재',
#  '’',
#  '[',
#  '해외',
#  '이모저모',
#  ']',
#  '미',
#  '메릴랜드',
#  '폭우',
#  '·',
#  '홍수',
#  '피해',
#  '…',
#  '1',
#  '명',
#  '실종',
#  '5월',
#  '아파트',
#  '분양',
#  '홍수',
#  '[',
#  '인사',
#  ']',
#  '보건복지부',
#  '외',
#  '[',
#  '인사',
#  ']',
#  '환경부',
#  '[',
#  '인사',
#  ']',
#  '보건복지부',
#  ';',
#  '환경부',
#  ';',
#  '부산',
#  '상공회의소',
#  '등',
#  '[',
#  '인사',
#  ']',
#  '보건복지부',
#  '外',
#  '선거',
#  '우편물',
#  '홍수',
#  '선거',
#  '우편물',
#  '홍수',
#  '한수원',
#  ',',
#  '낙동강',
#  '홍수',
#  '·',
#  '녹조',
#  '대비',
#  '운영',
#  '상황',
#  '최종',
#  '점검',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '…',
#  '국토부',
#  '5000',
#  '명',
#  '환경부',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '…',
#  '국토부',
#  '수자원',
#  '국',
#  ',',
#  '수자원공사',
#  '환경부',
#  '로',
#  '이',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '8일',
#  '부터',
#  '…',
#  '예산',
#  '·',
#  '인력',
#  '환경부',
#  '로',
#  '한수원',
#  ',',
#  '낙동강',
#  '홍수',
#  '·',
#  '녹조',
#  '대비',
#  '운영',
#  '상황',
#  '최종',
#  '점검',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '…',
#  '국토부',
#  '5000',
#  '명',
#  '환경부',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '따라',
#  '국토부',
#  '서',
#  '환경부',
#  '로',
#  '188',
#  '명',
#  '·',
#  '6천억',
#  '이',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '…',
#  '국토부',
#  '수자원',
#  '국',
#  ',',
#  '수자원공사',
#  '환경부',
#  '로',
#  '이',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '8일',
#  '부터',
#  '…',
#  '예산',
#  '·',
#  '인력',
#  '환경부',
#  '로',
#  '쿠바',
#  '홍수',
#  '로',
#  '5만',
#  '1천',
#  '명',
#  '긴급',
#  '대피',
#  '..',
#  '7',
#  '명',
#  '남성',
#  '모두',
#  '사망',
#  '쿠바',
#  '홍수',
#  '로',
#  '7',
#  '명',
#  '사망',
#  '·',
#  '2',
#  '명',
#  '실종',
#  '…',
#  '5만',
#  '1000',
#  '명',
#  '대피',
#  '쿠바',
#  '서',
#  '홍수',
#  '로',
#  '7',
#  '명',
#  '사망',
#  '·',
#  '2',
#  '명',
#  ...]

# %%
import nltk

# %%
text_contents = nltk.Text(tokens_contents, name='NMSC')
text_title = nltk.Text(tokens_title, name='NMSC')
text_keywords = nltk.Text(tokens_keywords, name='NMSC')

# %%
print(len(text_title.tokens)), print(len(text_contents.tokens)), print(len(text_keywords.tokens))
# Out:
# 97098
# 3129387
# 7871
# (None, None, None)

# %%
print(len(set(text_title.tokens))), print(len(set(text_contents.tokens))), print(len(set(text_keywords.tokens)))
# Out:
# 7565
# 61561
# 3
# (None, None, None)

# %%
from collections import namedtuple
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df_news, test_size=0.3, random_state=0)
df_train.shape, df_test.shape
# Out:
# ((5509, 7), (2362, 7))

# %%
df_train.head()
# Out:
#                            _id  \
# 2019  5cb3452485861022e6658dd5
# 5380  5cb3c54c85861022e6659af6
# 161   5cb32ba285861022e6658693
# 1319  5cb33c9685861022e6658b19
# 457   5cb32f9285861022e66587bb
#
#                                                contents keywords  \
# 2019  스리랑카 홍수와 산사태 피해 복구를 위해 써달라며 5만 달러(약 5,600만원)를 ...       홍수
# 5380  [이데일리 김경은 기자] 현대해상은 업계 최초로 모바일 및 인터넷으로 가입 가능한 ...       태풍
# 161   미국 하와이 주 카우아이 섬에 홍수와 산사태가 발생해 주민 200여 명이 헬기로 탈...       홍수
# 1319  (청주=연합뉴스) 변우열 기자 = 청주에 시간당 90㎜가 넘는 폭우가 쏟아지면서 미...       홍수
# 457   (자카르타=연합뉴스) 황철환 특파원 = 필리핀 남부 지역을 덮친 태풍으로 최소 18...       홍수
#
#                                      title  \
# 2019  ‘대장금’ 이영애, 스리랑카 홍수 피해 복구 위해 5만 달러 기부
# 5380            현대해상, 업계 최초 '온라인 풍수해보험' 판매
# 161           하와이 홍수에 산사태…헬기로 주민 200여 명 구조
# 1319             미호천 홍수경보…청주 주요하천 곳곳 범람 위기
# 457        필리핀 남부 태풍 강타로 최소 18명 사망·50여명 실종
#
#                                             token_title  \
# 2019  [‘, 대장금, ’, 이영애, ,, 스리랑카, 홍수, 피해, 복구, 위해, 5만, ...
# 5380      [현대, 해상, ,, 업계, 최초, ', 온라인, 풍수, 해, 보험, ', 판매]
# 161      [하와이, 홍수, 에, 산사태, …, 헬기, 로, 주민, 200, 여, 명, 구조]
# 1319           [미호천, 홍수, 경보, …, 청주, 주요, 하천, 곳곳, 범람, 위기]
# 457   [필리핀, 남부, 태풍, 강타, 로, 최소, 18, 명, 사망, ·, 50, 여명,...
#
#                                          token_contents token_keywords
# 2019  [스리랑카, 홍수, 와, 산사태, 피해, 복구, 를, 위해, 써, 달라, 며, 5만...           [홍수]
# 5380  [[, 이데일리, 김경, 은, 기자, ], 현, 대, 해상, 은, 업계, 최초, 로...           [태풍]
# 161   [미국, 하와이, 주, 카우아이, 섬, 에, 홍수, 와, 산사태, 가, 발생, 해,...           [홍수]
# 1319  [(, 청주, =, 연합뉴스, ), 변, 우열, 기자, =, 청주, 에, 시간, 당...           [홍수]
# 457   [(, 자카르타, =, 연합뉴스, ), 황철, 환, 특파원, =, 필리핀, 남부, ...           [홍수]

# %%
tagged_train_docs = [TaggedDocument(d, c) for d, c in df_train[['token_contents', 'token_keywords']].values]
tagged_test_docs = [TaggedDocument(d, c) for d, c in df_test[['token_contents', 'token_keywords']].values]

# %%
print(len(tagged_train_docs), len(tagged_test_docs))
# Out:
# 5509 2362

# %%
TaggedDocument = namedtuple('TaggedDocument', 'words tags')
TaggedDocument
# Out:
# __main__.TaggedDocument

# %%
import multiprocessing
cores = multiprocessing.cpu_count()
cores
# Out:
# 8

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from time import time
# Out:
# 2019-04-19 14:52:12,609 : WARNING : paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
# 2019-04-19 14:52:13,989 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
doc_vectorizer = Doc2Vec(
    dm=0,            # PV-DBOW / default 1
    dbow_words=1,    # w2v simultaneous with DBOW d2v / default 0
    window=8,        # distance between the predicted word and context words
    size=300,        # vector size
    alpha=0.025,     # learning-rate
    seed=1234,
    min_count=20,    # ignore with freq lower
    min_alpha=0.025, # min learning-rate
    workers=cores,   # multi cpu
    hs = 1,          # hierarchical softmax / default 0
    negative = 10,   # negative sampling / default 5
)
# Out:
# /home/jin/.local/lib/python3.6/site-packages/gensim/models/doc2vec.py:580: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
doc_vectorizer.build_vocab(tagged_train_docs)
print(str(doc_vectorizer))
# Out:
# 2019-04-19 16:01:47,140 : INFO : collecting all words and their counts
# 2019-04-19 16:01:47,141 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-04-19 16:01:47,369 : INFO : collected 53591 word types and 3 unique tags from a corpus of 5509 examples and 2204604 words
# 2019-04-19 16:01:47,369 : INFO : Loading a fresh vocabulary
# 2019-04-19 16:01:47,393 : INFO : effective_min_count=20 retains 7546 unique words (14% of original 53591, drops 46045)
# 2019-04-19 16:01:47,393 : INFO : effective_min_count=20 leaves 2043066 word corpus (92% of original 2204604, drops 161538)
# 2019-04-19 16:01:47,414 : INFO : deleting the raw counts dictionary of 53591 items
# 2019-04-19 16:01:47,416 : INFO : sample=0.001 downsamples 53 most-common words
# 2019-04-19 16:01:47,417 : INFO : downsampling leaves estimated 1627246 word corpus (79.6% of prior 2043066)
# 2019-04-19 16:01:47,423 : INFO : constructing a huffman tree from 7546 words
# 2019-04-19 16:01:47,548 : INFO : built huffman tree with maximum node depth 17
# 2019-04-19 16:01:47,556 : INFO : estimated required memory for 7546 words and 300 dimensions: 32452000 bytes
# 2019-04-19 16:01:47,557 : INFO : resetting layer weights
# Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)

# %%
doc_vectorizer.corpus_count, doc_vectorizer.iter
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (5509, 5)

# %%
doc_vectorizer

# %%
start = time()
for epoch in range(10):
    doc_vectorizer.train(tagged_train_docs, total_examples=doc_vectorizer.corpus_count, epochs=doc_vectorizer.iter)
    doc_vectorizer.alpha -= 0.002
    doc_vectorizer.min_alpha = doc_vectorizer.alpha

end = time()

print("Time: {}".format(end-start))
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# 2019-04-19 16:07:53,546 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-19 16:07:54,639 : INFO : EPOCH 1 - PROGRESS: at 7.37% examples, 110267 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:07:55,750 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 131144 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:07:56,772 : INFO : EPOCH 1 - PROGRESS: at 27.10% examples, 140323 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:07:57,845 : INFO : EPOCH 1 - PROGRESS: at 36.39% examples, 141220 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:07:58,881 : INFO : EPOCH 1 - PROGRESS: at 45.40% examples, 140941 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:07:59,895 : INFO : EPOCH 1 - PROGRESS: at 55.78% examples, 144488 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:00,901 : INFO : EPOCH 1 - PROGRESS: at 63.22% examples, 142045 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:01,935 : INFO : EPOCH 1 - PROGRESS: at 73.12% examples, 143606 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:03,048 : INFO : EPOCH 1 - PROGRESS: at 83.32% examples, 143993 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:04,147 : INFO : EPOCH 1 - PROGRESS: at 92.47% examples, 143137 words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:08:04,583 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-19 16:08:04,641 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-19 16:08:04,661 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-19 16:08:04,678 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-19 16:08:04,684 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-19 16:08:04,762 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-19 16:08:04,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-19 16:08:04,857 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-19 16:08:04,858 : INFO : EPOCH - 1 : training on 2204604 raw words (1632244 effective words) took 11.3s, 144357 effective words/s
# 2019-04-19 16:08:05,944 : INFO : EPOCH 2 - PROGRESS: at 7.19% examples, 109287 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:07,052 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 131646 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:08,176 : INFO : EPOCH 2 - PROGRESS: at 27.52% examples, 138528 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:09,184 : INFO : EPOCH 2 - PROGRESS: at 37.25% examples, 143608 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:10,186 : INFO : EPOCH 2 - PROGRESS: at 45.40% examples, 141047 words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:08:11,386 : INFO : EPOCH 2 - PROGRESS: at 56.18% examples, 141591 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:12,457 : INFO : EPOCH 2 - PROGRESS: at 66.00% examples, 143541 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:13,609 : INFO : EPOCH 2 - PROGRESS: at 75.95% examples, 143414 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:14,722 : INFO : EPOCH 2 - PROGRESS: at 86.62% examples, 144328 words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:08:15,768 : INFO : EPOCH 2 - PROGRESS: at 97.19% examples, 145187 words/s, in_qsize 8, out_qsize 0
# 2019-04-19 16:08:15,846 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-19 16:08:15,861 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-19 16:08:15,904 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-19 16:08:15,951 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-19 16:08:15,954 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-19 16:08:15,958 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-19 16:08:15,979 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-19 16:08:16,065 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-19 16:08:16,066 : INFO : EPOCH - 2 : training on 2204604 raw words (1633233 effective words) took 11.2s, 145755 effective words/s
# 2019-04-19 16:08:17,145 : INFO : EPOCH 3 - PROGRESS: at 7.37% examples, 111471 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:18,272 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 130850 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08:19,297 : INFO : EPOCH 3 - PROGRESS: at 27.10% examples, 140016 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:08
words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:13:51,902 : INFO : EPOCH 4 - PROGRESS: at 90.25% examples, 289650 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:13:52,210 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-19 16:13:52,242 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-19 16:13:52,291 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-19 16:13:52,299 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-19 16:13:52,313 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-19 16:13:52,322 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-19 16:13:52,322 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-19 16:13:52,345 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-19 16:13:52,345 : INFO : EPOCH - 4 : training on 2204604 raw words (1632901 effective words) took 5.6s, 293996 effective words/s
# 2019-04-19 16:13:53,355 : INFO : EPOCH 5 - PROGRESS: at 16.90% examples, 279533 words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:13:54,419 : INFO : EPOCH 5 - PROGRESS: at 34.67% examples, 279069 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:13:55,429 : INFO : EPOCH 5 - PROGRESS: at 53.66% examples, 286069 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:13:56,478 : INFO : EPOCH 5 - PROGRESS: at 72.55% examples, 289833 words/s, in_qsize 16, out_qsize 0
# 2019-04-19 16:13:57,486 : INFO : EPOCH 5 - PROGRESS: at 91.47% examples, 292498 words/s, in_qsize 15, out_qsize 0
# 2019-04-19 16:13:57,798 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-19 16:13:57,817 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-19 16:13:57,837 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-19 16:13:57,839 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-19 16:13:57,846 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-19 16:13:57,859 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-19 16:13:57,865 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-19 16:13:57,939 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-19 16:13:57,940 : INFO : EPOCH - 5 : training on 2204604 raw words (1633364 effective words) took 5.6s, 292094 effective words/s
# 2019-04-19 16:13:57,940 : INFO : training on a 11023020 raw words (8164620 effective words) took 27.9s, 292123 effective words/s
# Time: 364.39426255226135

# %%
model_name = 'Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)'
doc_vectorizer.save(model_name)
# Out:
# 2019-04-19 16:07:23,716 : INFO : saving Doc2Vec object under Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8), separately None
# 2019-04-19 16:07:23,723 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-04-19 16:07:23,944 : INFO : saved Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)

# %%
doc_vectorizer.wv.most_similar('홍수')
# Out:
# [('으로', 0.9197678565979004),
#  ('가', 0.9177134037017822),
#  ('이', 0.9176987409591675),
#  ('와', 0.9131097793579102),
#  ('은', 0.9124116897583008),
#  ('것', 0.9103720188140869),
#  ('\n\n', 0.9103573560714722),
#  ('에', 0.9101918935775757),
#  ('의', 0.9070377349853516),
#  ('에서', 0.9069863557815552)]

# %%
X_train = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_train_docs]
y_train = [doc.tags for doc in tagged_train_docs]

# %%
X_test = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_test_docs]
y_test = [doc.tags for doc in tagged_test_docs]

# %%
len(doc_vectorizer.infer_vector(['지진', '홍수의', '피해']))
# Out:
# 300

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.cluster import KMeans

# %%
clf = KMeans(n_clusters=3, init='k-means++', random_state=1).fit(X_train)
clf
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %%
pred = clf.predict(X_test)
# Out:
# 2362

# %%
cnt = 0
for i in pred:
    if i == 0:
        print(cnt+1)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
len(clf.cluster_centers_)
# Out:
# 3

# %%
accuracy_score(y_pred, y_test)
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:181: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   score = y_true == y_pred
# 0.0

# %%
pred
# Out:
# array([1, 0, 1, ..., 1, 0, 1], dtype=int32)
