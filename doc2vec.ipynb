# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np
import pickle
import os

# %%
from konlpy.tag import Komoran
from konlpy.tag import Twitter

# %% [markdown]
# <h3>
# 데이터베이스 : mongoDB<br>
# db : test<br>
# collection : results
# </h3>

# %%
client = MongoClient()
db = client.test
results = db.results

# %% [markdown]
# db에서 title, contents, keywords만 추출하여 데이터프레임에 저장

# %%
df_news = pd.DataFrame(list(results.find({}, {'title' : 'true', 'contents' : 'true', 'keywords' : 'true'})))

# %% [markdown]
# 재사용을 위해 pickle파일로 데이터프레임 저장

# %%
df_news.to_pickle("./df_news.pkl")

# %%
df_news = pd.read_pickle('./df_news.pkl')

# %%
df = df_news.iloc[:, 1:]

# %%
df
# Out:
#                                                contents keywords  \
# 0     동영상 뉴스\n■ 김은경 / 환경부 장관\n\n[앵커]\n얼마 전까지만 해도 우리나...       홍수
# 1     [한국경제TV 이근형 기자]\n지방 아파트 입주가 크게 늘면서 기존 전월세 임대인들...       홍수
# 2     선거홍보문자 관련 개인정보 침해상담 급증…한 달 간 상담 1만건 넘어\n개인정보 출...       홍수
# 3     "안녕하십니까. 이번 지방선거에 출마한 △△당 후보 ○○○입니다."\n6·13 지방...       홍수
# 4     미얀마 정부군의 탄압을 피해 국경을 넘어 방글라데시로 탈출한 이슬람계 소수민족 로힝...       홍수
# 5     난민 캠프 가건물 300채 파손…세 살배기, 흙더미에 깔려 숨져\n\n유엔 기구 "...       홍수
# 6     넥슨(대표 이정헌)의 신작 모바일 MMORPG ‘카이저(KAISER)’가 구글 플레...       홍수
# 7     조민희 로켓펀치 대표 (사진=신태현 기자)\n[이데일리 이재길 기자] “디지털 기술...       홍수
# 8     여주시장 선거에 출마한 이충우 한국당 후보의 답변... "주변 개발해 편의시설 만들...       홍수
# 9     6·13 지방선거에 출마한 대구경북 후보자들의 온갖 공약이 쏟아지고 있다. 저마다 ...       홍수
# 10    [한겨레] 염형철\n물개혁포럼 공동대표\n\n지난 90년 동안 수도권에서 발생한 가...       홍수
# 11    강물 범람으로 홍수가 난 쿠바의 한 마을 [AFP=연합뉴스]\n\n\n(멕시코시티=...       홍수
# 12    쿠바에서 최근 아열대성 폭풍으로 인해 홍수가 나는 바람에 7명이 숨지고 2명이 실종...       홍수
# 13    쿠바에서 최근 아열대성 폭풍으로 인해 홍수가 나는 바람에 7명이 숨지고 2명이 실종...       홍수
# 14    [서울경제] 쿠바에서 홍수가 발생해 7명이 숨지고 2명이 실종됐다고 공산당 기관지 ...       홍수
# 15    빠듯한 선거운동 일정 속 기관‧단체 정책질의 쏟아져\n편향 정책질의라도 답변 거부 ...       홍수
# 16    [동아일보]\n◇보건복지부 △기초의료보장과장 임은정 △질병관리본부 생명과학연구관리과...       홍수
# 17    (속초=연합뉴스) 6·13 지방선거 선거운동이 본격적으로 시작되면서 유권자들에게 발...       홍수
# 18    (속초=연합뉴스) 6·13 지방선거 선거운동이 본격적으로 시작되면서 유권자들에게 발...       홍수
# 19    조직개편후 홍수대비 급선무\n\n물관리일원화를 담은 정부조직법 개정안이 국무회의에서...       홍수
# 20    정부의 물관리 일원화 방침에 따라 국토교통부에서 환경부로 188명의 인력과 약 6천...       홍수
# 21    대전과 청주 사이 금강을 가로지르는 대청댐. 정부조직법 개정으로 수질뿐만 아니라 수...       홍수
# 22    수량·수질·재해예방 등 물관리 관련 법령 국무회의서 심의·의결\n\n국무회의 모습(...       홍수
# 23    물관리일원화 정부조직법 개정\n국토부서 188명·예산 6000억 이관\n국가·유역단...       홍수
# 24    현충일 앞두고 대전현충원 소방공무원 묘역 추모 발길\n\n강릉 석란정 순직 소방관 ...       홍수
# 25    MBC 시사프로그램 ‘PD수첩’이 15일 부영그룹의 공공 임대 아파트인 ‘사랑으로’...       홍수
# 26    동영상 뉴스\n[뉴스투데이]◀ 앵커 ▶\n\n미국 하와이 카우아이 섬에 하루 사이 ...       홍수
# 27    미국 하와이 주도 호놀룰루가 있는 오아후 섬 북서부 카우아이 섬에 홍수와 산사태가 ...       홍수
# 28    [한국경제TV 김현경 기자]\n\n\n미국 하와이에서 대규모 홍수 사태가 발생했다....       홍수
# 29    (로스앤젤레스=연합뉴스) 옥철 특파원 = 미국 하와이 주도 호놀룰루가 있는 오아후 ...       홍수
# ...                                                 ...      ...
# 7841  © News1\n\n(서울=뉴스1) 박정양 기자 = 제18호 태풍 '탈림'이 우리나...       태풍
# 7842  [머니투데이 이미호 기자] [조종묵 소방청장, 조기 상황판단회의 개최 ]\n\n조종...       태풍
# 7843  【서울=뉴시스】 지난 17일 오전 일본 남부 규슈(九州) 지방에 상륙한 제 18호 ...       태풍
# 7844  2017.9.14/뉴스1 © News1 임준현 인턴기자\n\n아침 최저 12~20도...       태풍
# 7845  【서울=뉴시스】고범준 기자 = 2일 오후 서울 동작구 기상청 국가기상센터에서 정관영...       태풍
# 7846  <앵커 멘트>\n\n초대형 태풍 '란'이 일본 열도를 강타하면서 인명 피해가 속출했...       태풍
# 7847  제23호 태풍 담레이가 베트남 중상부에 상륙한 가운데 태풍으로 인한 사망자수는 61...       태풍
# 7848  동영상 뉴스\n[뉴스투데이]어제 일본 가고시마현에 상륙한 18호 태풍 '탈림'이 일...       태풍
# 7849  【강릉=뉴시스】김경목 기자 = 16일 오후 제18호 태풍 '탈림(TALIM)'의 북...       태풍
# 7850  하승철 경남도 재난안전대책본부장(맨왼쪽)이 14일 도청에서 열린 태풍 대비 상황판단...       태풍
# 7851  맑은 하늘 아래 추억 남기기[연합뉴스 자료사진]\n\n\n(서울=연합뉴스) 성서호 ...       태풍
# 7852  [머니투데이 유희석 기자]\n제13호 태풍 '하토'(HATO)가 강타한 마카오 거리...       태풍
# 7853  동영상 뉴스\n제13호 태풍 '하토'가 오늘(23일) 홍콩과 마카오를 강타하면서 5...       태풍
# 7854  제13호 태풍 '하토'가 오늘(23일) 홍콩과 마카오를 강타하면서 5명이 사망하거나...       태풍
# 7855  [이미지출처=AP연합뉴스]\n\n[아시아경제 조슬기나 기자] 일본을 강타한 21호 ...       태풍
# 7856  [그래픽] 제18호 태풍 '탈림' 영향…제주 오후에 비\n\n\n16일까지 최고 1...       태풍
# 7857  도로공사 "오후 11시 돼야 정체 해소될 듯"\n\n가을 하늘 반기는 코스모스(구리...       태풍
# 7858  도로공사 "서울 방향 고속도로 정체 오후 7∼8시께 해소"\n\n가을 하늘 반기는 ...       태풍
# 7859  오늘 전국이 대체로 맑은 가운데 일교차가 큰 날씨가 이어지고 있습니다.\n\n내일 ...       태풍
# 7860  오늘 전국이 대체로 맑은 가운데 일교차가 큰 날씨가 이어지고 있습니다.\n\n내일 ...       태풍
# 7861  제18호 태풍 ‘탈림’ (사진=기상청)\n[이데일리 e뉴스 김민정 기자] 제18호 ...       태풍
# 7862  【대구=뉴시스】박준 기자 = 대구시 수성구청 전경. 2018.06.03(사진=뉴시스...       태풍
# 7863  제18호 태풍 ‘탈림’ (사진=기상청)\n[이데일리 e뉴스 김민정 기자] 제18호 ...       태풍
# 7864  【대구=뉴시스】박준 기자 = 대구시 수성구청 전경. 2018.06.03(사진=뉴시스...       태풍
# 7865  일본 열도가 18호 태풍 '탈림'의 상륙으로 수많은 사상자가 발생하고 있다.\n\n...       태풍
# 7866  [헤럴드경제=이슈섹션] 제 18호 태풍 탈림이 당초 예측과 달리 일본으로 방향을 튼...       태풍
# 7867  [서울경제] 태풍 ‘탈림’과 ‘독수리’에 이목이 쏠리고 있다.\n\n대만을 향하다가...       태풍
# 7868  [헤럴드경제=이슈섹션] 주말인 21일은 전국이 대체로 맑고 쾌청한 가을 날씨가 될 ...       태풍
# 7869  서울 롯데월드타워 전망대 [연합뉴스 자료사진]\n\n\n(서울=연합뉴스) 안홍석 기...       태풍
# 7870  동영상 뉴스\n[날씨] 전형적인 가을 날씨…오후부터 제주 태풍 영향\n\n[앵커]\...       태풍
#
#                                               title
# 0                          물관리 업무 일원화 첫걸음...달라지는 점은
# 1                            지방 입주 홍수에 세입자 구하기 '비상'
# 2                '내 정보 어디서 샜을까'…'선거 홍보문자' 홍수에 민원 급증
# 3           6·13 지방선거 후보자 홍보 문자 홍수에 '개인정보 침해' 민원 급증
# 4           로힝야족 난민촌에 찾아온 우기... 산사태, 홍수 위기에 그대로 노출돼
# 5           방글라데시 수용 로힝야족 난민 90만명, 우기 맞아 '전전긍긍'(종합)
# 6           ‘카이저’, IP 홍수 속 오리지널리티 뽐냈다…구글 게임매출 5위 올라
# 7            [ESF2018]조민희 대표 "데이터 홍수 속 '진주 찾기'가 핵심"
# 8                   이충우 "4대강은 잘 된 사업, 가뭄·홍수 대비에 도움"
# 9                 [사설] 선거공약 홍수, 좋으면 골라 당선자가 적극 활용하자
# 10               [왜냐면] 팔당호 수위 낮춰 수도권 대홍수 대비하자 / 염형철
# 11                  쿠바서 홍수로 7명 사망·2명 실종…5만1천명 긴급 대피
# 12                  쿠바서 홍수로 7명 사망·2명 실종…5만1천명 긴급 대피
# 13                쿠바서 홍수로 7명 사망·2명 실종...5만1천명 긴급 대피
# 14                  쿠바 홍수로 5만1천명 긴급 대피..7명 남성 모두 사망
# 15                   정책질의 홍수 속 지선 단체장 후보들 남모를 ‘속앓이’
# 16                                      [인사]보건복지부 外
# 17                                        선거 우편물 홍수
# 18                                        선거 우편물 홍수
# 19                 물관리일원화 관련법령 의결… 국토부 5000명 환경부 이관
# 20                물 관리 일원화 따라 국토부서 환경부로 188명·6천억 이관
# 21                  물관리 일원화…국토부 수자원국, 수자원공사 환경부로 이관
# 22                 물관리 일원화 따라 국토부서 환경부로 188명·6천억 이관
# 23                            통합물관리 8일부터…예산·인력 환경부로
# 24                    화마·홍수 맞서다 순직…소방영웅 128명 이곳에 있다
# 25         “분뇨 역류하고 옥상 홍수” 부영그룹 부실시공… 최순실 관계는? (영상)
# 26                       하와이 홍수·산사태…주민 2백여 명 필사의 탈출
# 27                   하와이 대형 홍수…주민 200여 명 헬기로 필사의 탈출
# 28                           하와이 홍수, "단 몇 분 만에 잠겼다"
# 29                     하와이 홍수, 헬기로 주민 200여 명 필사의 구조
# ...                                             ...
# 7841                   태풍 '탈림' 영향 예상…소방청, 비상근무태세 점검
# 7842                태풍 '탈림' 빠르게 북상…소방청 "비상근무 태세 점검"
# 7843                               태풍 '탈림' 일본 열도 강타
# 7844                    [오늘 날씨] 태풍 영향권 벗어나 맑음…일교차 커
# 7845                               태풍 노루 주말 제주권에 영향
# 7846                  [글로벌 브리핑] 태풍 日 열도 관통…인명 피해 속출
# 7847                  태풍 `담레이` 베트남 상륙…사망자 61명으로 늘어나
# 7848                      태풍 '탈림' 日 강타…주민 78만 명 대피령
# 7849                   태풍 탈림 북상…동해중부 앞바다 풍랑주의보 발효 중
# 7850                  16일 영향권…경남도 18호 태풍 ‘탈림’ 대응 분주
# 7851               [내일날씨] 대체로 '맑음'…태풍에 제주 최대 150㎜ 비
# 7852             태풍 '하토'에 마카오 초토화…3명 사망, 전력·수도 문제까지
# 7853                       홍콩·마카오 태풍 강타... 5명 사망·실종
# 7854                       홍콩·마카오 태풍 강타... 5명 사망·실종
# 7855                   '태풍 란' 日 강타…최소 5명 사망·132명 다쳐
# 7856                   제주도 육·해상 태풍 예비특보…대응태세 돌입(종합)
# 7857              태풍 지나고 화창한 휴일…나들이·벌초객으로 곳곳 정체(종합)
# 7858                 태풍 지나고 화창한 휴일…나들이·벌초객으로 도로 북새통
# 7859                         큰 일교차 주의…모레 제주도 태풍 영향권
# 7860                         큰 일교차 주의…모레 제주도 태풍 영향권
# 7861                   日 열도, 태풍 탈림 강타에 `비상`…40여명 사상
# 7862              "폭염 등 걱정마세요" 수성구, 자연재난 종합대책 마련 추진
# 7863                   日 열도, 태풍 탈림 강타에 `비상`…40여명 사상
# 7864              "폭염 등 걱정마세요" 수성구, 자연재난 종합대책 마련 추진
# 7865                日 18호 태풍 `탈림` 상륙에 2명 사망·3명 행방불명
# 7866                 태풍 ‘탈림’ 이어 ‘독수리’까지…쌍태풍 사태 ‘긴장’
# 7867  태풍 독수리는 또 뭐야? 쌍 태풍에 커지는 불안감↑ “시속 22km로 서북 서진”
# 7868                    쾌청한 주말…제주도 태풍 ‘란’ 영향권 강한 바람
# 7869                  [내일날씨] 태풍 지나고 전국 맑은 가운데 큰 일교차
# 7870                  [날씨] 전형적인 가을 날씨…오후부터 제주 태풍 영향
#
# [7871 rows x 3 columns]

# %% [markdown]
# 토크나이징을 위한 KoNLpy에서 twitter 모듈 함수화

# %%
twitter = Twitter()
def tokenizer_twitter_morphs(doc):
    return twitter.morphs(doc)

def tokenizer_twitter_noun(doc):
    return twitter.nouns(doc)

def tokenizer_twitter_pos(doc):
    return twitter.pos(doc, norm=True, stem=True)

komoran = Komoran()
def tokenizer_noun(doc):
    return komoran.nouns(doc)

def tokenizer_morphs(doc):
    return komoran.porphs(doc)
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# 토큰화 한 것들을 df_news에 추가

# %%
df_news['token_title'] = df_news['title'].apply(tokenizer_twitter_morphs)
df_news['token_contents'] = df_news['contents'].apply(tokenizer_twitter_morphs)
df_news['token_keywords'] = df_news['keywords'].apply(tokenizer_twitter_morphs)

# %%
# 명사만 추출
df_news['token_title_1'] = df_news['title'].apply(tokenizer_twitter_noun)
df_news['token_contents_1'] = df_news['contents'].apply(tokenizer_twitter_noun)
df_news['token_keywords_1'] = df_news['keywords'].apply(tokenizer_twitter_noun)

# %%
df_news.head()
# Out:
#                         _id  \
# 0  5cb32a7085861022e66585f2
# 1  5cb32a7285861022e66585f3
# 2  5cb32a7485861022e66585f4
# 3  5cb32a7585861022e66585f5
# 4  5cb32a7885861022e66585f6
#
#                                             contents keywords  \
# 0  동영상 뉴스\n■ 김은경 / 환경부 장관\n\n[앵커]\n얼마 전까지만 해도 우리나...       홍수
# 1  [한국경제TV 이근형 기자]\n지방 아파트 입주가 크게 늘면서 기존 전월세 임대인들...       홍수
# 2  선거홍보문자 관련 개인정보 침해상담 급증…한 달 간 상담 1만건 넘어\n개인정보 출...       홍수
# 3  "안녕하십니까. 이번 지방선거에 출마한 △△당 후보 ○○○입니다."\n6·13 지방...       홍수
# 4  미얀마 정부군의 탄압을 피해 국경을 넘어 방글라데시로 탈출한 이슬람계 소수민족 로힝...       홍수
#
#                                      title  \
# 0                 물관리 업무 일원화 첫걸음...달라지는 점은
# 1                   지방 입주 홍수에 세입자 구하기 '비상'
# 2       '내 정보 어디서 샜을까'…'선거 홍보문자' 홍수에 민원 급증
# 3  6·13 지방선거 후보자 홍보 문자 홍수에 '개인정보 침해' 민원 급증
# 4  로힝야족 난민촌에 찾아온 우기... 산사태, 홍수 위기에 그대로 노출돼
#
#                                          token_title  \
# 0             [물, 관리, 업무, 일원화, 첫걸음, ..., 달라지는, 점, 은]
# 1            [지방, 입주, 홍수, 에, 세, 입자, 구, 하기, ', 비상, ']
# 2  [', 내, 정보, 어디서, 샜을까, '…', 선거, 홍보, 문자, ', 홍수, 에...
# 3  [6, ·, 13, 지방선거, 후보자, 홍보, 문자, 홍수, 에, ', 개인정보, ...
# 4  [로힝야족, 난민, 촌, 에, 찾아온, 우기, ..., 산사태, ,, 홍수, 위기,...
#
#                                       token_contents token_keywords  \
# 0  [동영상, 뉴스, \n, ■, 김은경, /, 환경부, 장관, \n\n, [, 앵커,...           [홍수]
# 1  [[, 한국, 경제, TV, 이근형, 기자, ], \n, 지방, 아파트, 입, 주가...           [홍수]
# 2  [선거, 홍보, 문자, 관련, 개인정보, 침해, 상담, 급증, …, 한, 달, 간,...           [홍수]
# 3  [", 안녕하십니까, ., 이번, 지방선거, 에, 출마, 한, △△, 당, 후보, ...           [홍수]
# 4  [미얀마, 정부, 군, 의, 탄압, 을, 피해, 국경, 을, 넘어, 방글라데시, 로...           [홍수]
#
#                                token_title_1  \
# 0                   [물, 관리, 업무, 일원화, 첫걸음, 점]
# 1                        [지방, 홍수, 입자, 구, 비상]
# 2            [내, 정보, 선거, 홍보, 문자, 홍수, 민원, 급증]
# 3  [지방선거, 후보자, 홍보, 문자, 홍수, 개인정보, 침해, 민원, 급증]
# 4    [로힝야족, 난민, 촌, 우기, 산사태, 홍수, 위기, 그대로, 노출]
#
#                                     token_contents_1 token_keywords_1
# 0  [동영상, 뉴스, 김은경, 환경부, 장관, 앵커, 얼마, 전, 해도, 우리나라, 물...             [홍수]
# 1  [한국, 경제, 이근형, 기자, 지방, 아파트, 입, 주가, 크게, 기존, 전월세,...             [홍수]
# 2  [선거, 홍보, 문자, 관련, 개인정보, 침해, 상담, 급증, 달, 간, 상담, 개...             [홍수]
# 3  [안녕하십니까, 이번, 지방선거, 출마, 당, 후보, 지방선거, 각종, 선거운동, ...             [홍수]
# 4  [미얀마, 정부, 탄압, 피해, 국경, 방글라데시, 탈출, 이슬람, 소수민족, 로힝...             [홍수]

# %% [markdown]
# 토큰화 한 것들 리스트화

# %%
tokens_title = [t for d in df_news['token_title_1'] for t in d]
tokens_contents = [t for d in df_news['token_contents_1'] for t in d]
tokens_keywords = [t for d in df_news['token_keywords_1'] for t in d]

# %%
tokens_title
# Out:
# ['물',
#  '관리',
#  '업무',
#  '일원화',
#  '첫걸음',
#  '점',
#  '지방',
#  '홍수',
#  '입자',
#  '구',
#  '비상',
#  '내',
#  '정보',
#  '선거',
#  '홍보',
#  '문자',
#  '홍수',
#  '민원',
#  '급증',
#  '지방선거',
#  '후보자',
#  '홍보',
#  '문자',
#  '홍수',
#  '개인정보',
#  '침해',
#  '민원',
#  '급증',
#  '로힝야족',
#  '난민',
#  '촌',
#  '우기',
#  '산사태',
#  '홍수',
#  '위기',
#  '그대로',
#  '노출',
#  '방글라데시',
#  '수용',
#  '로힝야족',
#  '난민',
#  '우기',
#  '전전긍긍',
#  '종합',
#  '카이저',
#  '홍수',
#  '속',
#  '리지',
#  '널리',
#  '티',
#  '구글',
#  '게임',
#  '매출',
#  '위',
#  '조민희',
#  '대표',
#  '데이터',
#  '홍수',
#  '속',
#  '진주',
#  '찾기',
#  '핵심',
#  '이충',
#  '대강',
#  '사업',
#  '가뭄',
#  '홍수',
#  '대비',
#  '도움',
#  '사설',
#  '선거',
#  '공약',
#  '홍수',
#  '당선자',
#  '적극',
#  '활용',
#  '왜냐면',
#  '팔당호',
#  '수위',
#  '수도권',
#  '대홍수',
#  '대비',
#  '염',
#  '철',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '긴급',
#  '대피',
#  '명',
#  '남성',
#  '모두',
#  '사망',
#  '정책',
#  '질의',
#  '홍수',
#  '속',
#  '지선',
#  '단체',
#  '후보',
#  '앓이',
#  '인사',
#  '보건복지부',
#  '선거',
#  '우편물',
#  '홍수',
#  '선거',
#  '우편물',
#  '홍수',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '국토부',
#  '명',
#  '환경부',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '수자원',
#  '국',
#  '수자원공사',
#  '환경부',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '예산',
#  '인력',
#  '환경부',
#  '화마',
#  '홍수',
#  '순직',
#  '방영웅',
#  '명',
#  '곳',
#  '분뇨',
#  '역류',
#  '옥상',
#  '홍수',
#  '부영',
#  '그룹',
#  '부실',
#  '시공',
#  '최',
#  '실',
#  '관계',
#  '영상',
#  '하와이',
#  '홍수',
#  '산사태',
#  '주민',
#  '명',
#  '필사',
#  '탈출',
#  '하와이',
#  '대형',
#  '홍수',
#  '주민',
#  '여',
#  '명',
#  '헬기',
#  '필사',
#  '탈출',
#  '하와이',
#  '홍수',
#  '단',
#  '몇',
#  '분',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '후보',
#  '명',
#  '중',
#  '명',
#  '교육감',
#  '선거',
#  '무상',
#  '공약',
#  '홍수',
#  '신제품',
#  '맥주',
#  '국산',
#  '실종',
#  '외산',
#  '홍수',
#  '생산',
#  '기반',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '홍수',
#  '탈출',
#  '맹수',
#  '생포',
#  '사설',
#  '포퓰리즘',
#  '공약',
#  '홍수',
#  '아이',
#  '미래',
#  '교육감',
#  '분단',
#  '장벽',
#  '린다',
#  '민족',
#  '젖줄',
#  '임진강',
#  '남북',
#  '교류',
#  '장',
#  '뉴욕',
#  '지금',
#  '가상',
#  '화폐',
#  '컨퍼런스',
#  '홍수',
#  '현장',
#  '메릴랜드주',
#  '친',
#  '홍수',
#  '마을',
#  '쑥대밭',
#  '통일부',
#  '북한',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '유발',
#  '북한',
#  '단신',
#  '김영남',
#  '케냐',
#  '대통령',
#  '홍수',
#  '피해',
#  '위로',
#  '이',
#  '시각',
#  '세계',
#  '홍수',
#  '동물원',
#  '맹수',
#  '집단',
#  '탈주',
#  '알베르토',
#  '강타',
#  '부지역',
#  '홍수',
#  '사망',
#  '명',
#  '실종자',
#  '다수',
#  '메릴랜드주',
#  '홍수',
#  '비상',
#  '사태',
#  '선포',
#  '지구촌',
#  '물난리',
#  '동부',
#  '메릴랜드',
#  '주',
#  '폭우',
#  '홍수',
#  '비상',
#  '사태',
#  '선포',
#  '영상',
#  '메릴랜드',
#  '기록',
#  '폭우',
#  '홍수',
#  '비상',
#  '사태',
#  '선포',
#  '메릴랜드주',
#  '홍수',
#  '메릴랜드주',
#  '홍수',
#  '명',
#  '실종',
#  '공군',
#  '출신',
#  '방위',
#  '이스라엘',
#  '사해',
#  '근처',
#  '홍수',
#  '청소년',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '이스라엘',
#  '사해',
#  '근처',
#  '홍수',
#  '청소년',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '이스라엘',
#  '사해',
#  '근처',
#  '홍수',
#  '청소년',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '울릉도',
#  '빗물',
#  '저장',
#  '시설',
#  '건립',
#  '홍수',
#  '농업',
#  '용수로',
#  '활용',
#  '거리',
#  '곳곳',
#  '불법',
#  '광고',
#  '물',
#  '홍수',
#  '김포시',
#  '현수막',
#  '전쟁',
#  '선포',
#  '미국',
#  '메릴랜드주',
#  '홍수',
#  '비상',
#  '사태',
#  '선포',
#  '신',
#  '만점',
#  '비법',
#  '홍수',
#  '피해',
#  '분양',
#  '홍수',
#  '청약',
#  '거래',
#  '절벽',
#  '부동산',
#  '시장',
#  '악재',
#  '해외',
#  '이모저모',
#  '메릴랜드',
#  '폭우',
#  '홍수',
#  '피해',
#  '명',
#  '실종',
#  '아파트',
#  '분양',
#  '홍수',
#  '인사',
#  '보건복지부',
#  '외',
#  '인사',
#  '환경부',
#  '인사',
#  '보건복지부',
#  '환경부',
#  '부산',
#  '상공회의소',
#  '등',
#  '인사',
#  '보건복지부',
#  '선거',
#  '우편물',
#  '홍수',
#  '선거',
#  '우편물',
#  '홍수',
#  '한수원',
#  '낙동강',
#  '홍수',
#  '녹조',
#  '대비',
#  '운영',
#  '상황',
#  '최종',
#  '점검',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '국토부',
#  '명',
#  '환경부',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '수자원',
#  '국',
#  '수자원공사',
#  '환경부',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '예산',
#  '인력',
#  '환경부',
#  '한수원',
#  '낙동강',
#  '홍수',
#  '녹조',
#  '대비',
#  '운영',
#  '상황',
#  '최종',
#  '점검',
#  '물',
#  '관리',
#  '일원화',
#  '관련',
#  '법령',
#  '의결',
#  '국토부',
#  '명',
#  '환경부',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '수자원',
#  '국',
#  '수자원공사',
#  '환경부',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '예산',
#  '인력',
#  '환경부',
#  '쿠바',
#  '홍수',
#  '긴급',
#  '대피',
#  '명',
#  '남성',
#  '모두',
#  '사망',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '명',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '긴급',
#  '대피',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '종합',
#  '물',
#  '관리',
#  '환경부',
#  '일원화',
#  '하천',
#  '관리기능',
#  '국토부',
#  '존치',
#  '물',
#  '관리',
#  '일원화',
#  '정부조직법',
#  '개정',
#  '통합',
#  '물',
#  '관리',
#  '개시',
#  '물',
#  '관리',
#  '일원화',
#  '정부조직법',
#  '개정',
#  '통합',
#  '물',
#  '관리',
#  '개시',
#  '화마',
#  '홍수',
#  '순직',
#  '방영웅',
#  '명',
#  '곳',
#  '분뇨',
#  '역류',
#  '옥상',
#  '홍수',
#  '부영',
#  '그룹',
#  '부실',
#  '시공',
#  '최',
#  '실',
#  '관계',
#  '영상',
#  '분뇨',
#  '역류',
#  '옥상',
#  '홍수',
#  '부영',
#  '그룹',
#  '부실',
#  '시공',
#  '최',
#  '실',
#  '관계',
#  '영상',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '수자원',
#  '국',
#  '수자원공사',
#  '환경부',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '예산',
#  '인력',
#  '환경부',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '국토부',
#  '명',
#  '환경부',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '명',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '긴급',
#  '대피',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '쿠바',
#  '홍수',
#  '긴급',
#  '대피',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '하와이',
#  '홍수',
#  '산사태',
#  '주민',
#  '명',
#  '필사',
#  '탈출',
#  '하와이',
#  '대형',
#  '홍수',
#  '주민',
#  '여',
#  '명',
#  '헬기',
#  '필사',
#  '탈출',
#  '하와이',
#  '홍수',
#  '단',
#  '몇',
#  '분',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '후보',
#  '명',
#  '중',
#  '명',
#  '교육감',
#  '선거',
#  '무상',
#  '공약',
#  '홍수',
#  '인사',
#  '환경부',
#  '물',
#  '관리',
#  '일원화',
#  '국토부',
#  '환경부',
#  '명',
#  '관',
#  '통합',
#  '물',
#  '관리',
#  '국토부',
#  '명',
#  '환경부',
#  '하와이',
#  '홍수',
#  '산사태',
#  '주민',
#  '명',
#  '필사',
#  '탈출',
#  '하와이',
#  '대형',
#  '홍수',
#  '주민',
#  '여',
#  '명',
#  '헬기',
#  '필사',
#  '탈출',
#  '하와이',
#  '홍수',
#  '단',
#  '몇',
#  '분',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '하와이',
#  '홍수',
#  '헬기',
#  '주민',
#  '여',
#  '명',
#  '필사',
#  '구조',
#  '후보',
#  '명',
#  '중',
#  '명',
#  '교육감',
#  '선거',
#  '무상',
#  '공약',
#  '홍수',
#  '쿠바',
#  '홍수',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '명',
#  '긴급',
#  '대피',
#  '쿠바',
#  '홍수',
#  '명',
#  '긴급',
#  '대피',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '쿠바',
#  '홍수',
#  '긴급',
#  '대피',
#  '명',
#  '사망',
#  '명',
#  '실종',
#  '인사',
#  '환경부',
#  '신제품',
#  '맥주',
#  '국산',
#  '실종',
#  '외산',
#  '홍수',
#  '생산',
#  '기반',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '신제품',
#  '맥주',
#  '국산',
#  '실종',
#  '외산',
#  '홍수',
#  '생산',
#  '기반',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '피해',
#  '가중',
#  '홍수',
#  '탈출',
#  '맹수',
#  '생포',
#  '사설',
#  '포퓰리즘',
#  '공약',
#  '홍수',
#  '아이',
#  '미래',
#  '교육감',
#  '분단',
#  '장벽',
#  '린다',
#  '민족',
#  '젖줄',
#  '임진강',
#  '남북',
#  '교류',
#  '장',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '등',
#  '피해',
#  '가중',
#  '통일부',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '피해',
#  '가중',
#  '홍수',
#  '탈출',
#  '맹수',
#  '생포',
#  '사설',
#  '포퓰리즘',
#  '공약',
#  '홍수',
#  '아이',
#  '미래',
#  '교육감',
#  '분단',
#  '장벽',
#  '린다',
#  '민족',
#  '젖줄',
#  '임진강',
#  '남북',
#  '교류',
#  '장',
#  '뉴욕',
#  '지금',
#  '가상',
#  '화폐',
#  '컨퍼런스',
#  '홍수',
#  '현장',
#  '메릴랜드주',
#  '친',
#  '홍수',
#  '마을',
#  '쑥대밭',
#  '통일부',
#  '북한',
#  '산림',
#  '황폐',
#  '홍수',
#  '산사태',
#  '유발',
#  '현장',
#  '메릴랜드주',
#  '친',
#  '홍수',
#  '마을',
#  '쑥대밭',
#  ...]

# %% [markdown]
# nltk 추가

# %%
import nltk

# %%
text_contents = nltk.Text(tokens_contents, name='NMSC')
text_title = nltk.Text(tokens_title, name='NMSC')
text_keywords = nltk.Text(tokens_keywords, name='NMSC')

# %%
print(len(text_title.tokens)), print(len(text_contents.tokens)), print(len(text_keywords.tokens))
# Out:
# 57929
# 1486152
# 7871
# (None, None, None)

# %% [markdown]
# 중복 제거

# %%
print(len(set(text_title.tokens))), print(len(set(text_contents.tokens))), print(len(set(text_keywords.tokens)))
# Out:
# 5192
# 29208
# 3
# (None, None, None)

# %%
from collections import namedtuple
from sklearn.model_selection import train_test_split

# %% [markdown]
# 클러스터링이 잘 되었는지 확인 하기 위해 df_news를 트레이닝셋과 테스트 셋으로 분리

# %%
df_train, df_test = train_test_split(df_news, test_size=0.3, random_state=0)
df_train.shape, df_test.shape
# Out:
# ((5509, 10), (2362, 10))

# %%
df_train.head()
# Out:
#                            _id  \
# 2019  5cb3452485861022e6658dd5
# 5380  5cb3c54c85861022e6659af6
# 161   5cb32ba285861022e6658693
# 1319  5cb33c9685861022e6658b19
# 457   5cb32f9285861022e66587bb
#
#                                                contents keywords  \
# 2019  스리랑카 홍수와 산사태 피해 복구를 위해 써달라며 5만 달러(약 5,600만원)를 ...       홍수
# 5380  [이데일리 김경은 기자] 현대해상은 업계 최초로 모바일 및 인터넷으로 가입 가능한 ...       태풍
# 161   미국 하와이 주 카우아이 섬에 홍수와 산사태가 발생해 주민 200여 명이 헬기로 탈...       홍수
# 1319  (청주=연합뉴스) 변우열 기자 = 청주에 시간당 90㎜가 넘는 폭우가 쏟아지면서 미...       홍수
# 457   (자카르타=연합뉴스) 황철환 특파원 = 필리핀 남부 지역을 덮친 태풍으로 최소 18...       홍수
#
#                                      title  \
# 2019  ‘대장금’ 이영애, 스리랑카 홍수 피해 복구 위해 5만 달러 기부
# 5380            현대해상, 업계 최초 '온라인 풍수해보험' 판매
# 161           하와이 홍수에 산사태…헬기로 주민 200여 명 구조
# 1319             미호천 홍수경보…청주 주요하천 곳곳 범람 위기
# 457        필리핀 남부 태풍 강타로 최소 18명 사망·50여명 실종
#
#                                             token_title  \
# 2019  [‘, 대장금, ’, 이영애, ,, 스리랑카, 홍수, 피해, 복구, 위해, 5만, ...
# 5380      [현대, 해상, ,, 업계, 최초, ', 온라인, 풍수, 해, 보험, ', 판매]
# 161      [하와이, 홍수, 에, 산사태, …, 헬기, 로, 주민, 200, 여, 명, 구조]
# 1319           [미호천, 홍수, 경보, …, 청주, 주요, 하천, 곳곳, 범람, 위기]
# 457   [필리핀, 남부, 태풍, 강타, 로, 최소, 18, 명, 사망, ·, 50, 여명,...
#
#                                          token_contents token_keywords  \
# 2019  [스리랑카, 홍수, 와, 산사태, 피해, 복구, 를, 위해, 써, 달라, 며, 5만...           [홍수]
# 5380  [[, 이데일리, 김경, 은, 기자, ], 현, 대, 해상, 은, 업계, 최초, 로...           [태풍]
# 161   [미국, 하와이, 주, 카우아이, 섬, 에, 홍수, 와, 산사태, 가, 발생, 해,...           [홍수]
# 1319  [(, 청주, =, 연합뉴스, ), 변, 우열, 기자, =, 청주, 에, 시간, 당...           [홍수]
# 457   [(, 자카르타, =, 연합뉴스, ), 황철, 환, 특파원, =, 필리핀, 남부, ...           [홍수]
#
#                                  token_title_1  \
# 2019  [대장금, 이영애, 스리랑카, 홍수, 피해, 복구, 위해, 달러, 기부]
# 5380         [현대, 해상, 업계, 최초, 온라인, 풍수, 보험, 판매]
# 161           [하와이, 홍수, 산사태, 헬기, 주민, 여, 명, 구조]
# 1319         [미호천, 홍수, 경보, 청주, 하천, 곳곳, 범람, 위기]
# 457       [필리핀, 남부, 태풍, 강타, 최소, 명, 사망, 여명, 실종]
#
#                                        token_contents_1 token_keywords_1
# 2019  [스리랑카, 홍수, 산사태, 피해, 복구, 위해, 달라, 달러, 약, 를, 기부, ...             [홍수]
# 5380  [이데일리, 김경, 기자, 해상, 업계, 최초, 모바일, 및, 인터넷, 가입, 온라...             [태풍]
# 161   [미국, 하와이, 주, 섬, 홍수, 산사태, 발생, 주민, 여, 명, 헬기, 탈출,...             [홍수]
# 1319  [청주, 연합뉴스, 변, 우열, 기자, 청주, 시간, 폭우, 미호천, 홍수, 경보,...             [홍수]
# 457   [자카르타, 연합뉴스, 황철, 환, 특파원, 필리핀, 남부, 지역, 친, 태풍, 최...             [홍수]

# %% [markdown]
# doc2vec 모델을 학습하기 위한 TaggedDocument 형태로 전환

# %%
tagged_train_docs = [TaggedDocument(d, c) for d, c in df_train[['token_contents', 'token_keywords']].values]
tagged_test_docs = [TaggedDocument(d, c) for d, c in df_test[['token_contents', 'token_keywords']].values]

# %%
print(len(tagged_train_docs), len(tagged_test_docs))
# Out:
# 5509 2362

# %%
import multiprocessing
cores = multiprocessing.cpu_count()
cores
# Out:
# 8

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from time import time
# Out:
# 2019-04-19 14:52:12,609 : WARNING : paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
# 2019-04-19 14:52:13,989 : INFO : 'pattern' package not found; tag filters are not available for English

# %% [markdown]
# doc2vec 모델의 하이퍼파라미터 선언

# %%
doc_vectorizer = Doc2Vec(
    dm=0,            # PV-DBOW / default 1
    dbow_words=1,    # w2v simultaneous with DBOW d2v / default 0
    window=8,        # distance between the predicted word and context words
    size=300,        # vector size
    alpha=0.025,     # learning-rate
    seed=1234,
    min_count=20,    # ignore with freq lower
    min_alpha=0.025, # min learning-rate
    workers=cores,   # multi cpu
    hs = 1,          # hierarchical softmax / default 0
    negative = 10,   # negative sampling / default 5
)
# Out:
# /home/jin/.local/lib/python3.6/site-packages/gensim/models/doc2vec.py:580: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
doc_vectorizer.build_vocab(tagged_train_docs)
print(str(doc_vectorizer))
# Out:
# 2019-04-22 00:55:11,666 : INFO : collecting all words and their counts
# 2019-04-22 00:55:11,669 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-04-22 00:55:11,918 : INFO : collected 53591 word types and 3 unique tags from a corpus of 5509 examples and 2204604 words
# 2019-04-22 00:55:11,918 : INFO : Loading a fresh vocabulary
# 2019-04-22 00:55:11,938 : INFO : effective_min_count=20 retains 7546 unique words (14% of original 53591, drops 46045)
# 2019-04-22 00:55:11,939 : INFO : effective_min_count=20 leaves 2043066 word corpus (92% of original 2204604, drops 161538)
# 2019-04-22 00:55:11,958 : INFO : deleting the raw counts dictionary of 53591 items
# 2019-04-22 00:55:11,959 : INFO : sample=0.001 downsamples 53 most-common words
# 2019-04-22 00:55:11,960 : INFO : downsampling leaves estimated 1627246 word corpus (79.6% of prior 2043066)
# 2019-04-22 00:55:11,968 : INFO : constructing a huffman tree from 7546 words
# 2019-04-22 00:55:12,086 : INFO : built huffman tree with maximum node depth 17
# 2019-04-22 00:55:12,094 : INFO : estimated required memory for 7546 words and 300 dimensions: 32452000 bytes
# 2019-04-22 00:55:12,094 : INFO : resetting layer weights
# Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)

# %%
doc_vectorizer.corpus_count, doc_vectorizer.iter
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (5509, 5)

# %% [markdown]
# 학습시작!

# %%
start = time()

for epoch in range(10):
    doc_vectorizer.train(tagged_train_docs, total_examples=doc_vectorizer.corpus_count, epochs=doc_vectorizer.iter)
    doc_vectorizer.alpha -= 0.002
    doc_vectorizer.min_alpha = doc_vectorizer.alpha

end = time()

print("Time: {}".format(end-start))
# Out:
# /home/jin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   after removing the cwd from sys.path.
# 2019-04-22 00:55:23,762 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 00:55:24,872 : INFO : EPOCH 1 - PROGRESS: at 7.19% examples, 107055 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:25,989 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 129682 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:27,122 : INFO : EPOCH 1 - PROGRESS: at 27.52% examples, 136806 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:28,266 : INFO : EPOCH 1 - PROGRESS: at 37.74% examples, 139560 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:29,289 : INFO : EPOCH 1 - PROGRESS: at 48.18% examples, 143665 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:30,312 : INFO : EPOCH 1 - PROGRESS: at 56.18% examples, 141122 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:31,313 : INFO : EPOCH 1 - PROGRESS: at 65.77% examples, 143950 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:32,314 : INFO : EPOCH 1 - PROGRESS: at 74.15% examples, 143336 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:33,328 : INFO : EPOCH 1 - PROGRESS: at 83.32% examples, 143022 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:34,331 : INFO : EPOCH 1 - PROGRESS: at 92.61% examples, 143599 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:34,765 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:55:34,826 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:55:34,876 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:55:34,878 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:55:34,950 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:55:34,975 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:55:34,982 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:55:35,069 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:55:35,069 : INFO : EPOCH - 1 : training on 2204604 raw words (1632744 effective words) took 11.3s, 144443 effective words/s
# 2019-04-22 00:55:36,143 : INFO : EPOCH 2 - PROGRESS: at 7.37% examples, 111823 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:37,254 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 132144 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:38,367 : INFO : EPOCH 2 - PROGRESS: at 27.52% examples, 139421 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:39,378 : INFO : EPOCH 2 - PROGRESS: at 36.39% examples, 140896 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:40,436 : INFO : EPOCH 2 - PROGRESS: at 46.29% examples, 142778 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:41,470 : INFO : EPOCH 2 - PROGRESS: at 56.18% examples, 144415 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:42,483 : INFO : EPOCH 2 - PROGRESS: at 64.49% examples, 143727 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:43,545 : INFO : EPOCH 2 - PROGRESS: at 74.08% examples, 144612 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:55:44,557 : INFO : EPOCH 2 - PROGRESS: at 83.32% examples, 144205 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:45,559 : INFO : EPOCH 2 - PROGRESS: at 93.08% examples, 145361 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:55:45,990 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:55:46,058 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:55:46,083 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:55:46,120 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:55:46,124 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:55:46,155 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:55:46,163 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:55:46,250 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:55:46,251 : INFO : EPOCH - 2 : training on 2204604 raw words (1632528 effective words) took 11.2s, 146034 effective words/s
# 2019-04-22 00:55:47,330 : INFO : EPOCH 3 - PROGRESS: at 7.19% examples, 109995 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:48,421 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 133020 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:49,474 : INFO : EPOCH 3 - PROGRESS: at 27.10% examples, 140351 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:50,531 : INFO : EPOCH 3 - PROGRESS: at 36.81% examples, 143490 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:51,531 : INFO : EPOCH 3 - PROGRESS: at 45.40% examples, 142364 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:52,603 : INFO : EPOCH 3 - PROGRESS: at 55.47% examples, 143384 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:53,649 : INFO : EPOCH 3 - PROGRESS: at 64.80% examples, 144962 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:54,673 : INFO : EPOCH 3 - PROGRESS: at 74.46% examples, 146386 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:55,735 : INFO : EPOCH 3 - PROGRESS: at 83.32% examples, 144266 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:56,787 : INFO : EPOCH 3 - PROGRESS: at 93.61% examples, 145490 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:55:57,185 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:55:57,218 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:55:57,233 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:55:57,249 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:55:57,264 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:55:57,301 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:55:57,307 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:55:57,359 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:55:57,359 : INFO : EPOCH - 3 : training on 2204604 raw words (1633161 effective words) took 11.1s, 147055 effective words/s
# 2019-04-22 00:55:58,422 : INFO : EPOCH 4 - PROGRESS: at 7.37% examples, 112863 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:55:59,506 : INFO : EPOCH 4 - PROGRESS: at 17.32% examples, 134313 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:00,619 : INFO : EPOCH 4 - PROGRESS: at 27.52% examples, 140917 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:01,640 : INFO : EPOCH 4 - PROGRESS: at 36.81% examples, 143398 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:02,649 : INFO : EPOCH 4 - PROGRESS: at 45.89% examples, 143369 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:03,657 : INFO : EPOCH 4 - PROGRESS: at 55.78% examples, 145586 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:04,704 : INFO : EPOCH 4 - PROGRESS: at 64.49% examples, 145078 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:05,738 : INFO : EPOCH 4 - PROGRESS: at 74.08% examples, 146267 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:06,779 : INFO : EPOCH 4 - PROGRESS: at 83.35% examples, 145230 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:07,831 : INFO : EPOCH 4 - PROGRESS: at 93.61% examples, 146325 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:08,258 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:56:08,267 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:56:08,273 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:56:08,319 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:56:08,331 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:56:08,365 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:56:08,396 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:56:08,457 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:56:08,457 : INFO : EPOCH - 4 : training on 2204604 raw words (1632514 effective words) took 11.1s, 147130 effective words/s
# 2019-04-22 00:56:09,539 : INFO : EPOCH 5 - PROGRESS: at 7.19% examples, 109686 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:10,655 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 131249 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:11,799 : INFO : EPOCH 5 - PROGRESS: at 27.52% examples, 137535 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:12,928 : INFO : EPOCH 5 - PROGRESS: at 37.74% examples, 140598 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:13,929 : INFO : EPOCH 5 - PROGRESS: at 47.21% examples, 142506 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:15,058 : INFO : EPOCH 5 - PROGRESS: at 56.71% examples, 141157 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:16,103 : INFO : EPOCH 5 - PROGRESS: at 66.55% examples, 143617 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:17,155 : INFO : EPOCH 5 - PROGRESS: at 75.95% examples, 144274 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:18,166 : INFO : EPOCH 5 - PROGRESS: at 86.17% examples, 146012 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:19,171 : INFO : EPOCH 5 - PROGRESS: at 94.95% examples, 145034 words/s, in_qsize 12, out_qsize 0
# 2019-04-22 00:56:19,361 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:56:19,425 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:56:19,428 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:56:19,452 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:56:19,493 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:56:19,514 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:56:19,541 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:56:19,601 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:56:19,601 : INFO : EPOCH - 5 : training on 2204604 raw words (1632591 effective words) took 11.1s, 146539 effective words/s
# 2019-04-22 00:56:19,601 : INFO : training on a 11023020 raw words (8163538 effective words) took 55.8s, 146198 effective words/s
# 2019-04-22 00:56:19,602 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 00:56:20,668 : INFO : EPOCH 1 - PROGRESS: at 7.37% examples, 112776 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:21,758 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 133784 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:22,792 : INFO : EPOCH 1 - PROGRESS: at 27.10% examples, 141720 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:23,793 : INFO : EPOCH 1 - PROGRESS: at 36.39% examples, 144785 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:24,812 : INFO : EPOCH 1 - PROGRESS: at 45.40% examples, 144282 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:25,871 : INFO : EPOCH 1 - PROGRESS: at 55.47% examples, 145291 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:26,925 : INFO : EPOCH 1 - PROGRESS: at 64.49% examples, 145547 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:27,940 : INFO : EPOCH 1 - PROGRESS: at 73.77% examples, 146170 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:28,985 : INFO : EPOCH 1 - PROGRESS: at 83.32% examples, 145849 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:30,011 : INFO : EPOCH 1 - PROGRESS: at 93.08% examples, 146507 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:30,440 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:56:30,487 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:56:30,524 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:56:30,543 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:56:30,580 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:56:30,595 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:56:30,610 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:56:30,680 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:56:30,681 : INFO : EPOCH - 1 : training on 2204604 raw words (1632746 effective words) took 11.1s, 147411 effective words/s
# 2019-04-22 00:56:31,770 : INFO : EPOCH 2 - PROGRESS: at 7.19% examples, 109057 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:32,905 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 129816 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:34,044 : INFO : EPOCH 2 - PROGRESS: at 27.52% examples, 136711 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:35,150 : INFO : EPOCH 2 - PROGRESS: at 37.74% examples, 140709 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:36,221 : INFO : EPOCH 2 - PROGRESS: at 48.18% examples, 143359 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:37,254 : INFO : EPOCH 2 - PROGRESS: at 58.40% examples, 146081 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:38,314 : INFO : EPOCH 2 - PROGRESS: at 66.55% examples, 143845 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:39,336 : INFO : EPOCH 2 - PROGRESS: at 75.95% examples, 144990 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:40,375 : INFO : EPOCH 2 - PROGRESS: at 86.17% examples, 146237 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:41,455 : INFO : EPOCH 2 - PROGRESS: at 96.59% examples, 146318 words/s, in_qsize 9, out_qsize 0
# 2019-04-22 00:56:41,577 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:56:41,588 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:56:41,592 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:56:41,611 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:56:41,667 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:56:41,674 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:56:41,684 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:56:41,775 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:56:41,776 : INFO : EPOCH - 2 : training on 2204604 raw words (1632984 effective words) took 11.1s, 147229 effective words/s
# 2019-04-22 00:56:42,840 : INFO : EPOCH 3 - PROGRESS: at 7.19% examples, 111313 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:43,915 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 134807 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:44,920 : INFO : EPOCH 3 - PROGRESS: at 27.10% examples, 143786 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:46,033 : INFO : EPOCH 3 - PROGRESS: at 36.39% examples, 142466 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:47,094 : INFO : EPOCH 3 - PROGRESS: at 46.29% examples, 144009 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:48,094 : INFO : EPOCH 3 - PROGRESS: at 56.18% examples, 146233 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:49,125 : INFO : EPOCH 3 - PROGRESS: at 64.49% examples, 144944 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:50,155 : INFO : EPOCH 3 - PROGRESS: at 73.77% examples, 145410 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:56:51,236 : INFO : EPOCH 3 - PROGRESS: at 83.75% examples, 145338 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:52,240 : INFO : EPOCH 3 - PROGRESS: at 93.61% examples, 146413 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:52,643 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:56:52,689 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:56:52,707 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:56:52,713 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:56:52,800 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:56:52,809 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:56:52,825 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:56:52,891 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:56:52,891 : INFO : EPOCH - 3 : training on 2204604 raw words (1632397 effective words) took 11.1s, 146896 effective words/s
# 2019-04-22 00:56:53,947 : INFO : EPOCH 4 - PROGRESS: at 7.19% examples, 112381 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:55,051 : INFO : EPOCH 4 - PROGRESS: at 17.32% examples, 133732 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:56,086 : INFO : EPOCH 4 - PROGRESS: at 27.10% examples, 141597 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:57,205 : INFO : EPOCH 4 - PROGRESS: at 36.83% examples, 142427 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:58,266 : INFO : EPOCH 4 - PROGRESS: at 47.23% examples, 145370 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:56:59,273 : INFO : EPOCH 4 - PROGRESS: at 56.18% examples, 144940 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:00,280 : INFO : EPOCH 4 - PROGRESS: at 65.28% examples, 146236 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:01,291 : INFO : EPOCH 4 - PROGRESS: at 74.46% examples, 146844 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:02,340 : INFO : EPOCH 4 - PROGRESS: at 83.32% examples, 144886 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:03,461 : INFO : EPOCH 4 - PROGRESS: at 94.12% examples, 145758 words/s, in_qsize 14, out_qsize 0
# 2019-04-22 00:57:03,691 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:57:03,746 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:57:03,854 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:57:03,856 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:57:03,857 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:57:03,860 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:57:03,863 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:57:03,946 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:57:03,946 : INFO : EPOCH - 4 : training on 2204604 raw words (1633675 effective words) took 11.1s, 147807 effective words/s
# 2019-04-22 00:57:05,035 : INFO : EPOCH 5 - PROGRESS: at 7.37% examples, 110518 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:06,166 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 130104 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:07,197 : INFO : EPOCH 5 - PROGRESS: at 27.10% examples, 139152 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:08,209 : INFO : EPOCH 5 - PROGRESS: at 35.14% examples, 137446 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:09,258 : INFO : EPOCH 5 - PROGRESS: at 45.16% examples, 140364 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:10,266 : INFO : EPOCH 5 - PROGRESS: at 55.07% examples, 142969 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:11,303 : INFO : EPOCH 5 - PROGRESS: at 63.31% examples, 141966 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:12,328 : INFO : EPOCH 5 - PROGRESS: at 72.55% examples, 142851 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:13,466 : INFO : EPOCH 5 - PROGRESS: at 83.32% examples, 143725 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:14,479 : INFO : EPOCH 5 - PROGRESS: at 93.08% examples, 144767 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:14,906 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:57:14,924 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:57:14,951 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:57:14,990 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:57:14,992 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:57:15,030 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:57:15,047 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:57:15,109 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:57:15,110 : INFO : EPOCH - 5 : training on 2204604 raw words (1632526 effective words) took 11.2s, 146277 effective words/s
# 2019-04-22 00:57:15,110 : INFO : training on a 11023020 raw words (8164328 effective words) took 55.5s, 147084 effective words/s
# 2019-04-22 00:57:15,110 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 00:57:16,170 : INFO : EPOCH 1 - PROGRESS: at 7.19% examples, 112021 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:17,276 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 133394 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:18,444 : INFO : EPOCH 1 - PROGRESS: at 27.52% examples, 137988 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:19,445 : INFO : EPOCH 1 - PROGRESS: at 35.92% examples, 138442 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:20,542 : INFO : EPOCH 1 - PROGRESS: at 45.16% examples, 137318 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:21,640 : INFO : EPOCH 1 - PROGRESS: at 55.78% examples, 140522 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:22,673 : INFO : EPOCH 1 - PROGRESS: at 64.49% examples, 140966 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:23,687 : INFO : EPOCH 1 - PROGRESS: at 73.53% examples, 141324 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:24,906 : INFO : EPOCH 1 - PROGRESS: at 83.32% examples, 139711 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:25,949 : INFO : EPOCH 1 - PROGRESS: at 93.61% examples, 141443 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:26,360 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:57:26,362 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:57:26,453 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:57:26,465 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:57:26,507 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:57:26,532 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:57:26,568 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:57:26,604 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:57:26,605 : INFO : EPOCH - 1 : training on 2204604 raw words (1633164 effective words) took 11.5s, 142121 effective words/s
# 2019-04-22 00:57:27,670 : INFO : EPOCH 2 - PROGRESS: at 7.19% examples, 111526 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:28,761 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 133913 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:29,807 : INFO : EPOCH 2 - PROGRESS: at 27.10% examples, 141300 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:30,825 : INFO : EPOCH 2 - PROGRESS: at 35.92% examples, 142169 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:31,853 : INFO : EPOCH 2 - PROGRESS: at 43.78% examples, 137984 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:32,868 : INFO : EPOCH 2 - PROGRESS: at 51.68% examples, 135083 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:33,903 : INFO : EPOCH 2 - PROGRESS: at 60.23% examples, 135389 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:34,992 : INFO : EPOCH 2 - PROGRESS: at 69.00% examples, 136040 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:36,186 : INFO : EPOCH 2 - PROGRESS: at 79.51% examples, 136842 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:37,191 : INFO : EPOCH 2 - PROGRESS: at 88.71% examples, 137819 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:38,099 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:57:38,166 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:57:38,267 : INFO : EPOCH 2 - PROGRESS: at 98.15% examples, 137151 words/s, in_qsize 5, out_qsize 1
# 2019-04-22 00:57:38,267 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:57:38,302 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:57:38,307 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:57:38,337 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:57:38,352 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:57:38,412 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:57:38,412 : INFO : EPOCH - 2 : training on 2204604 raw words (1632672 effective words) took 11.8s, 138310 effective words/s
# 2019-04-22 00:57:39,486 : INFO : EPOCH 3 - PROGRESS: at 7.37% examples, 112044 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:40,487 : INFO : EPOCH 3 - PROGRESS: at 16.48% examples, 132484 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:41,621 : INFO : EPOCH 3 - PROGRESS: at 25.50% examples, 132292 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:42,673 : INFO : EPOCH 3 - PROGRESS: at 34.25% examples, 134015 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:43,710 : INFO : EPOCH 3 - PROGRESS: at 43.78% examples, 136716 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:44,718 : INFO : EPOCH 3 - PROGRESS: at 52.57% examples, 136375 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:45,749 : INFO : EPOCH 3 - PROGRESS: at 60.23% examples, 134673 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:57:46,758 : INFO : EPOCH 3 - PROGRESS: at 68.85% examples, 136778 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:47,791 : INFO : EPOCH 3 - PROGRESS: at 77.26% examples, 136025 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:48,844 : INFO : EPOCH 3 - PROGRESS: at 86.17% examples, 135910 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:49,892 : INFO : EPOCH 3 - PROGRESS: at 95.50% examples, 136052 words/s, in_qsize 11, out_qsize 0
# 2019-04-22 00:57:50,049 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:57:50,078 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:57:50,127 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:57:50,131 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:57:50,191 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:57:50,246 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:57:50,255 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:57:50,344 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:57:50,345 : INFO : EPOCH - 3 : training on 2204604 raw words (1633066 effective words) took 11.9s, 136894 effective words/s
# 2019-04-22 00:57:51,522 : INFO : EPOCH 4 - PROGRESS: at 7.19% examples, 100891 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:52,584 : INFO : EPOCH 4 - PROGRESS: at 16.65% examples, 122842 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:53,610 : INFO : EPOCH 4 - PROGRESS: at 24.67% examples, 125746 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:54,614 : INFO : EPOCH 4 - PROGRESS: at 32.93% examples, 128610 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:55,737 : INFO : EPOCH 4 - PROGRESS: at 41.73% examples, 128644 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:56,787 : INFO : EPOCH 4 - PROGRESS: at 51.68% examples, 131130 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:57,881 : INFO : EPOCH 4 - PROGRESS: at 60.23% examples, 131046 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:58,886 : INFO : EPOCH 4 - PROGRESS: at 68.85% examples, 133577 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:57:59,898 : INFO : EPOCH 4 - PROGRESS: at 78.33% examples, 135012 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:00,905 : INFO : EPOCH 4 - PROGRESS: at 87.48% examples, 136054 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:01,939 : INFO : EPOCH 4 - PROGRESS: at 97.57% examples, 137184 words/s, in_qsize 7, out_qsize 1
# 2019-04-22 00:58:01,944 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:01,946 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:01,948 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:01,952 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:01,999 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:02,020 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:02,033 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:02,135 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:02,136 : INFO : EPOCH - 4 : training on 2204604 raw words (1632471 effective words) took 11.8s, 138475 effective words/s
# 2019-04-22 00:58:03,204 : INFO : EPOCH 5 - PROGRESS: at 7.37% examples, 112554 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:04,315 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 132449 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:05,532 : INFO : EPOCH 5 - PROGRESS: at 27.59% examples, 135306 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:06,605 : INFO : EPOCH 5 - PROGRESS: at 37.74% examples, 140610 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:07,763 : INFO : EPOCH 5 - PROGRESS: at 48.76% examples, 142433 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:08,794 : INFO : EPOCH 5 - PROGRESS: at 58.40% examples, 144200 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:09,873 : INFO : EPOCH 5 - PROGRESS: at 66.49% examples, 141949 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:10,881 : INFO : EPOCH 5 - PROGRESS: at 74.88% examples, 141822 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:11,933 : INFO : EPOCH 5 - PROGRESS: at 83.75% examples, 140390 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:12,955 : INFO : EPOCH 5 - PROGRESS: at 93.08% examples, 140968 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:13,412 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:13,440 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:13,505 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:13,655 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:13,671 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:13,713 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:13,730 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:13,737 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:13,737 : INFO : EPOCH - 5 : training on 2204604 raw words (1632812 effective words) took 11.6s, 140777 effective words/s
# 2019-04-22 00:58:13,738 : INFO : training on a 11023020 raw words (8164185 effective words) took 58.6s, 139257 effective words/s
# 2019-04-22 00:58:13,738 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 00:58:14,861 : INFO : EPOCH 1 - PROGRESS: at 7.19% examples, 105698 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:15,954 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 130162 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:16,987 : INFO : EPOCH 1 - PROGRESS: at 27.10% examples, 139169 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:17,998 : INFO : EPOCH 1 - PROGRESS: at 36.39% examples, 142409 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:19,026 : INFO : EPOCH 1 - PROGRESS: at 45.40% examples, 142125 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:20,047 : INFO : EPOCH 1 - PROGRESS: at 55.47% examples, 144325 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:21,048 : INFO : EPOCH 1 - PROGRESS: at 63.73% examples, 143912 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:22,050 : INFO : EPOCH 1 - PROGRESS: at 72.55% examples, 144025 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:23,228 : INFO : EPOCH 1 - PROGRESS: at 83.32% examples, 144172 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:24,229 : INFO : EPOCH 1 - PROGRESS: at 93.61% examples, 146058 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:24,621 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:24,656 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:24,675 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:24,732 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:24,737 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:24,790 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:24,823 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:24,851 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:24,852 : INFO : EPOCH - 1 : training on 2204604 raw words (1632311 effective words) took 11.1s, 146904 effective words/s
# 2019-04-22 00:58:25,916 : INFO : EPOCH 2 - PROGRESS: at 7.37% examples, 112775 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:27,002 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 134160 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:28,183 : INFO : EPOCH 2 - PROGRESS: at 27.52% examples, 137910 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:29,291 : INFO : EPOCH 2 - PROGRESS: at 37.74% examples, 141540 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:30,316 : INFO : EPOCH 2 - PROGRESS: at 48.18% examples, 145256 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:31,327 : INFO : EPOCH 2 - PROGRESS: at 56.71% examples, 143821 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:32,391 : INFO : EPOCH 2 - PROGRESS: at 66.31% examples, 145066 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:33,466 : INFO : EPOCH 2 - PROGRESS: at 75.95% examples, 145593 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:34,595 : INFO : EPOCH 2 - PROGRESS: at 86.62% examples, 146056 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:35,608 : INFO : EPOCH 2 - PROGRESS: at 97.19% examples, 147152 words/s, in_qsize 8, out_qsize 0
# 2019-04-22 00:58:35,635 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:35,690 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:35,724 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:35,794 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:35,796 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:35,800 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:35,835 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:35,903 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:35,903 : INFO : EPOCH - 2 : training on 2204604 raw words (1631903 effective words) took 11.0s, 147697 effective words/s
# 2019-04-22 00:58:36,954 : INFO : EPOCH 3 - PROGRESS: at 7.19% examples, 113015 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:38,079 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 132702 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:39,213 : INFO : EPOCH 3 - PROGRESS: at 27.59% examples, 138795 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:40,329 : INFO : EPOCH 3 - PROGRESS: at 37.74% examples, 141955 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:41,490 : INFO : EPOCH 3 - PROGRESS: at 48.68% examples, 143366 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:42,562 : INFO : EPOCH 3 - PROGRESS: at 59.21% examples, 146226 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:43,566 : INFO : EPOCH 3 - PROGRESS: at 68.51% examples, 147916 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:44,609 : INFO : EPOCH 3 - PROGRESS: at 77.91% examples, 147374 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:45,628 : INFO : EPOCH 3 - PROGRESS: at 86.62% examples, 146342 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:46,645 : INFO : EPOCH 3 - PROGRESS: at 97.19% examples, 147377 words/s, in_qsize 8, out_qsize 0
# 2019-04-22 00:58:46,646 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:46,726 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:46,780 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:46,817 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:46,820 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:46,860 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:46,871 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:46,880 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:46,881 : INFO : EPOCH - 3 : training on 2204604 raw words (1632357 effective words) took 11.0s, 148744 effective words/s
# 2019-04-22 00:58:47,958 : INFO : EPOCH 4 - PROGRESS: at 7.37% examples, 111458 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:49,057 : INFO : EPOCH 4 - PROGRESS: at 17.32% examples, 132504 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:50,193 : INFO : EPOCH 4 - PROGRESS: at 27.52% examples, 138737 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:51,348 : INFO : EPOCH 4 - PROGRESS: at 37.74% examples, 140682 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:58:52,494 : INFO : EPOCH 4 - PROGRESS: at 48.76% examples, 142812 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:53,581 : INFO : EPOCH 4 - PROGRESS: at 59.21% examples, 145358 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:54,625 : INFO : EPOCH 4 - PROGRESS: at 68.51% examples, 146403 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:55,659 : INFO : EPOCH 4 - PROGRESS: at 78.38% examples, 147040 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:56,702 : INFO : EPOCH 4 - PROGRESS: at 87.66% examples, 146454 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:58:57,670 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:58:57,735 : INFO : EPOCH 4 - PROGRESS: at 97.73% examples, 146722 words/s, in_qsize 6, out_qsize 1
# 2019-04-22 00:58:57,735 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:58:57,756 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:58:57,772 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:58:57,785 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:58:57,846 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:58:57,848 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:58:57,912 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:58:57,912 : INFO : EPOCH - 4 : training on 2204604 raw words (1632941 effective words) took 11.0s, 148057 effective words/s
# 2019-04-22 00:58:58,972 : INFO : EPOCH 5 - PROGRESS: at 7.19% examples, 111905 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:00,093 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 132373 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:01,215 : INFO : EPOCH 5 - PROGRESS: at 27.52% examples, 139207 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:02,217 : INFO : EPOCH 5 - PROGRESS: at 37.25% examples, 144428 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:03,252 : INFO : EPOCH 5 - PROGRESS: at 46.36% examples, 143527 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:04,287 : INFO : EPOCH 5 - PROGRESS: at 56.18% examples, 145038 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:05,291 : INFO : EPOCH 5 - PROGRESS: at 64.80% examples, 145373 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:59:06,331 : INFO : EPOCH 5 - PROGRESS: at 73.35% examples, 143974 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:07,409 : INFO : EPOCH 5 - PROGRESS: at 83.32% examples, 144116 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:08,431 : INFO : EPOCH 5 - PROGRESS: at 92.61% examples, 144307 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:08,923 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:59:08,932 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:59:08,936 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:59:08,958 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:59:09,033 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:59:09,098 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:59:09,116 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:59:09,130 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:59:09,131 : INFO : EPOCH - 5 : training on 2204604 raw words (1633058 effective words) took 11.2s, 145601 effective words/s
# 2019-04-22 00:59:09,131 : INFO : training on a 11023020 raw words (8162570 effective words) took 55.4s, 147358 effective words/s
# 2019-04-22 00:59:09,131 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 00:59:10,228 : INFO : EPOCH 1 - PROGRESS: at 7.37% examples, 109529 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:11,346 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 130291 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:12,428 : INFO : EPOCH 1 - PROGRESS: at 27.10% examples, 137079 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:13,442 : INFO : EPOCH 1 - PROGRESS: at 35.92% examples, 138975 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:14,448 : INFO : EPOCH 1 - PROGRESS: at 45.40% examples, 141323 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:15,450 : INFO : EPOCH 1 - PROGRESS: at 53.64% examples, 139396 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:16,502 : INFO : EPOCH 1 - PROGRESS: at 62.92% examples, 140730 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:17,627 : INFO : EPOCH 1 - PROGRESS: at 72.55% examples, 140885 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:18,797 : INFO : EPOCH 1 - PROGRESS: at 83.35% examples, 141529 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:19,835 : INFO : EPOCH 1 - PROGRESS: at 93.61% examples, 143147 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:20,245 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:59:20,251 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:59:20,259 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:59:20,310 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:59:20,321 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:59:20,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:59:20,358 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:59:20,390 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:59:20,390 : INFO : EPOCH - 1 : training on 2204604 raw words (1632259 effective words) took 11.3s, 145016 effective words/s
# 2019-04-22 00:59:21,455 : INFO : EPOCH 2 - PROGRESS: at 7.37% examples, 112902 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:22,530 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 134831 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:23,538 : INFO : EPOCH 2 - PROGRESS: at 26.72% examples, 141394 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:59:24,553 : INFO : EPOCH 2 - PROGRESS: at 35.92% examples, 143983 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:25,670 : INFO : EPOCH 2 - PROGRESS: at 45.40% examples, 142340 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:26,864 : INFO : EPOCH 2 - PROGRESS: at 56.18% examples, 142720 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:27,956 : INFO : EPOCH 2 - PROGRESS: at 66.00% examples, 144154 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:28,978 : INFO : EPOCH 2 - PROGRESS: at 75.95% examples, 146101 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:30,011 : INFO : EPOCH 2 - PROGRESS: at 85.73% examples, 146562 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:31,024 : INFO : EPOCH 2 - PROGRESS: at 95.50% examples, 146864 words/s, in_qsize 11, out_qsize 0
# 2019-04-22 00:59:31,202 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:59:31,262 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:59:31,300 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:59:31,311 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:59:31,317 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:59:31,354 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:59:31,358 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:59:31,439 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:59:31,439 : INFO : EPOCH - 2 : training on 2204604 raw words (1632760 effective words) took 11.0s, 147811 effective words/s
# 2019-04-22 00:59:32,495 : INFO : EPOCH 3 - PROGRESS: at 7.37% examples, 113563 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:33,597 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 133531 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:34,608 : INFO : EPOCH 3 - PROGRESS: at 27.10% examples, 142589 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:35,647 : INFO : EPOCH 3 - PROGRESS: at 35.92% examples, 142408 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:36,658 : INFO : EPOCH 3 - PROGRESS: at 44.76% examples, 141495 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:37,665 : INFO : EPOCH 3 - PROGRESS: at 54.64% examples, 143895 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:59:38,732 : INFO : EPOCH 3 - PROGRESS: at 62.92% examples, 142240 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:39,866 : INFO : EPOCH 3 - PROGRESS: at 72.55% examples, 142038 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 00:59:41,031 : INFO : EPOCH 3 - PROGRESS: at 83.23% examples, 142571 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 00:59:42,131 : INFO : EPOCH 3 - PROGRESS: at 94.12% examples, 143960 words/s, in_qsize 14, out_qsize 0
# 2019-04-22 00:59:42,434 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 00:59:42,480 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 00:59:42,497 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 00:59:42,572 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 00:59:42,585 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 00:59:42,602 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 00:59:42,607 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 00:59:42,639 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 00:59:42,640 : INFO : EPOCH - 3 : training on 2204604 raw words (1632048 effective words) took 11.2s, 145739 effective words/s
# ...
# 2019-04-22 01:03:24,060 : INFO : EPOCH 3 - PROGRESS: at 56.71% examples, 144415 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:25,078 : INFO : EPOCH 3 - PROGRESS: at 65.77% examples, 145524 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:03:26,088 : INFO : EPOCH 3 - PROGRESS: at 74.88% examples, 146231 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:27,182 : INFO : EPOCH 3 - PROGRESS: at 85.02% examples, 145818 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:28,216 : INFO : EPOCH 3 - PROGRESS: at 95.19% examples, 146510 words/s, in_qsize 12, out_qsize 0
# 2019-04-22 01:03:28,496 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:03:28,525 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:03:28,528 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:03:28,541 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:03:28,543 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:03:28,571 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:03:28,606 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:03:28,678 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:03:28,678 : INFO : EPOCH - 3 : training on 2204604 raw words (1633152 effective words) took 11.1s, 147507 effective words/s
# 2019-04-22 01:03:29,729 : INFO : EPOCH 4 - PROGRESS: at 7.19% examples, 113025 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:30,742 : INFO : EPOCH 4 - PROGRESS: at 16.90% examples, 136789 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:31,757 : INFO : EPOCH 4 - PROGRESS: at 25.38% examples, 137997 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:32,860 : INFO : EPOCH 4 - PROGRESS: at 35.09% examples, 139954 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:34,000 : INFO : EPOCH 4 - PROGRESS: at 45.89% examples, 142601 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:35,079 : INFO : EPOCH 4 - PROGRESS: at 56.18% examples, 144451 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:36,108 : INFO : EPOCH 4 - PROGRESS: at 65.28% examples, 145380 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:03:37,138 : INFO : EPOCH 4 - PROGRESS: at 74.88% examples, 146617 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:38,144 : INFO : EPOCH 4 - PROGRESS: at 84.06% examples, 146038 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:39,205 : INFO : EPOCH 4 - PROGRESS: at 94.12% examples, 146297 words/s, in_qsize 14, out_qsize 0
# 2019-04-22 01:03:39,467 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:03:39,526 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:03:39,581 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:03:39,644 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:03:39,669 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:03:39,670 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:03:39,677 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:03:39,731 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:03:39,731 : INFO : EPOCH - 4 : training on 2204604 raw words (1632915 effective words) took 11.1s, 147767 effective words/s
# 2019-04-22 01:03:40,823 : INFO : EPOCH 5 - PROGRESS: at 7.19% examples, 108672 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:41,936 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 130967 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:43,014 : INFO : EPOCH 5 - PROGRESS: at 27.10% examples, 137860 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:44,020 : INFO : EPOCH 5 - PROGRESS: at 35.92% examples, 139878 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:03:45,080 : INFO : EPOCH 5 - PROGRESS: at 45.40% examples, 140566 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:46,121 : INFO : EPOCH 5 - PROGRESS: at 55.38% examples, 142467 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:03:47,181 : INFO : EPOCH 5 - PROGRESS: at 64.49% examples, 143072 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:03:48,196 : INFO : EPOCH 5 - PROGRESS: at 73.35% examples, 143160 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:49,274 : INFO : EPOCH 5 - PROGRESS: at 83.32% examples, 143389 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:50,422 : INFO : EPOCH 5 - PROGRESS: at 94.12% examples, 144042 words/s, in_qsize 14, out_qsize 0
# 2019-04-22 01:03:50,663 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:03:50,687 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:03:50,758 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:03:50,775 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:03:50,789 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:03:50,801 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:03:50,806 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:03:50,895 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:03:50,895 : INFO : EPOCH - 5 : training on 2204604 raw words (1632801 effective words) took 11.2s, 146294 effective words/s
# 2019-04-22 01:03:50,895 : INFO : training on a 11023020 raw words (8165059 effective words) took 55.9s, 146140 effective words/s
# 2019-04-22 01:03:50,896 : INFO : training model with 8 workers on 7546 vocabulary and 300 features, using sg=1 hs=1 sample=0.001 negative=10 window=8
# 2019-04-22 01:03:51,947 : INFO : EPOCH 1 - PROGRESS: at 7.19% examples, 112866 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:53,065 : INFO : EPOCH 1 - PROGRESS: at 17.32% examples, 133346 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:54,196 : INFO : EPOCH 1 - PROGRESS: at 27.52% examples, 139520 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:55,360 : INFO : EPOCH 1 - PROGRESS: at 37.74% examples, 140950 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:56,372 : INFO : EPOCH 1 - PROGRESS: at 48.18% examples, 145156 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:57,390 : INFO : EPOCH 1 - PROGRESS: at 57.02% examples, 144610 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:58,426 : INFO : EPOCH 1 - PROGRESS: at 66.55% examples, 145911 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:03:59,516 : INFO : EPOCH 1 - PROGRESS: at 75.86% examples, 145574 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:00,601 : INFO : EPOCH 1 - PROGRESS: at 86.62% examples, 146765 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:01,646 : INFO : EPOCH 1 - PROGRESS: at 96.97% examples, 147360 words/s, in_qsize 8, out_qsize 0
# 2019-04-22 01:04:01,663 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:04:01,732 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:04:01,758 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:04:01,759 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:04:01,798 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:04:01,822 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:04:01,849 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:04:01,899 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:04:01,900 : INFO : EPOCH - 1 : training on 2204604 raw words (1633423 effective words) took 11.0s, 148474 effective words/s
# 2019-04-22 01:04:02,957 : INFO : EPOCH 2 - PROGRESS: at 7.37% examples, 113673 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:04,064 : INFO : EPOCH 2 - PROGRESS: at 17.32% examples, 133346 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:05,187 : INFO : EPOCH 2 - PROGRESS: at 27.52% examples, 139871 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:06,209 : INFO : EPOCH 2 - PROGRESS: at 37.25% examples, 144206 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:07,285 : INFO : EPOCH 2 - PROGRESS: at 47.21% examples, 144809 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:08,309 : INFO : EPOCH 2 - PROGRESS: at 56.49% examples, 145285 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:09,327 : INFO : EPOCH 2 - PROGRESS: at 65.29% examples, 145359 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:10,372 : INFO : EPOCH 2 - PROGRESS: at 74.88% examples, 146358 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:11,395 : INFO : EPOCH 2 - PROGRESS: at 84.59% examples, 146236 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:12,405 : INFO : EPOCH 2 - PROGRESS: at 94.12% examples, 146553 words/s, in_qsize 14, out_qsize 0
# 2019-04-22 01:04:12,713 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:04:12,769 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:04:12,772 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:04:12,790 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:04:12,815 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:04:12,863 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:04:12,872 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:04:12,942 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:04:12,943 : INFO : EPOCH - 2 : training on 2204604 raw words (1632398 effective words) took 11.0s, 147856 effective words/s
# 2019-04-22 01:04:14,009 : INFO : EPOCH 3 - PROGRESS: at 7.19% examples, 111380 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:15,077 : INFO : EPOCH 3 - PROGRESS: at 17.32% examples, 135233 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:16,081 : INFO : EPOCH 3 - PROGRESS: at 26.72% examples, 141894 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:17,112 : INFO : EPOCH 3 - PROGRESS: at 36.03% examples, 143826 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:18,136 : INFO : EPOCH 3 - PROGRESS: at 45.40% examples, 144769 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:19,162 : INFO : EPOCH 3 - PROGRESS: at 55.78% examples, 147484 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:20,174 : INFO : EPOCH 3 - PROGRESS: at 63.73% examples, 145500 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:21,203 : INFO : EPOCH 3 - PROGRESS: at 73.12% examples, 145857 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:22,257 : INFO : EPOCH 3 - PROGRESS: at 83.32% examples, 146909 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:23,268 : INFO : EPOCH 3 - PROGRESS: at 92.61% examples, 146989 words/s, in_qsize 16, out_qsize 0
# 2019-04-22 01:04:23,722 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:04:23,756 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:04:23,776 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:04:23,783 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:04:23,825 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:04:23,831 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:04:23,858 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:04:23,947 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:04:23,947 : INFO : EPOCH - 3 : training on 2204604 raw words (1632631 effective words) took 11.0s, 148394 effective words/s
# 2019-04-22 01:04:25,004 : INFO : EPOCH 4 - PROGRESS: at 7.19% examples, 112210 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:26,101 : INFO : EPOCH 4 - PROGRESS: at 17.32% examples, 133947 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:27,115 : INFO : EPOCH 4 - PROGRESS: at 27.10% examples, 142728 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:28,127 : INFO : EPOCH 4 - PROGRESS: at 35.92% examples, 143448 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:29,178 : INFO : EPOCH 4 - PROGRESS: at 45.40% examples, 143729 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:30,321 : INFO : EPOCH 4 - PROGRESS: at 56.18% examples, 145066 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:31,325 : INFO : EPOCH 4 - PROGRESS: at 65.77% examples, 147370 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:32,359 : INFO : EPOCH 4 - PROGRESS: at 74.46% examples, 146580 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:33,415 : INFO : EPOCH 4 - PROGRESS: at 84.59% examples, 146716 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:34,453 : INFO : EPOCH 4 - PROGRESS: at 94.65% examples, 147279 words/s, in_qsize 13, out_qsize 0
# 2019-04-22 01:04:34,723 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:04:34,748 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:04:34,772 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:04:34,795 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:04:34,837 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:04:34,861 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:04:34,864 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:04:34,936 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:04:34,936 : INFO : EPOCH - 4 : training on 2204604 raw words (1632983 effective words) took 11.0s, 148637 effective words/s
# 2019-04-22 01:04:36,006 : INFO : EPOCH 5 - PROGRESS: at 7.37% examples, 112423 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:37,091 : INFO : EPOCH 5 - PROGRESS: at 17.32% examples, 133858 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:38,207 : INFO : EPOCH 5 - PROGRESS: at 27.52% examples, 140386 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:39,314 : INFO : EPOCH 5 - PROGRESS: at 37.74% examples, 143550 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:40,437 : INFO : EPOCH 5 - PROGRESS: at 48.18% examples, 144333 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:41,439 : INFO : EPOCH 5 - PROGRESS: at 57.89% examples, 146463 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:42,455 : INFO : EPOCH 5 - PROGRESS: at 66.31% examples, 145489 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:43,566 : INFO : EPOCH 5 - PROGRESS: at 75.95% examples, 145374 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:44,584 : INFO : EPOCH 5 - PROGRESS: at 85.79% examples, 146169 words/s, in_qsize 15, out_qsize 0
# 2019-04-22 01:04:45,587 : INFO : EPOCH 5 - PROGRESS: at 96.06% examples, 147251 words/s, in_qsize 10, out_qsize 0
# 2019-04-22 01:04:45,787 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-04-22 01:04:45,823 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-04-22 01:04:45,849 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-04-22 01:04:45,863 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-04-22 01:04:45,878 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-04-22 01:04:45,894 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-04-22 01:04:45,917 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-04-22 01:04:46,027 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-04-22 01:04:46,027 : INFO : EPOCH - 5 : training on 2204604 raw words (1632262 effective words) took 11.1s, 147200 effective words/s
# 2019-04-22 01:04:46,027 : INFO : training on a 11023020 raw words (8163697 effective words) took 55.1s, 148078 effective words/s
# Time: 562.2662925720215

# %% [markdown]
# 모델 저장

# %%
model_name_1 = 'Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)'
doc_vectorizer.save(model_name_1)
# Out:
# 2019-04-22 01:07:34,372 : INFO : saving Doc2Vec object under Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8), separately None
# 2019-04-22 01:07:34,376 : WARNING : this function is deprecated, use smart_open.open instead
# 2019-04-22 01:07:34,618 : INFO : saved Doc2Vec(dbow+w,d300,n10,hs,w8,mc20,s0.001,t8)

# %% [markdown]
# 조사가 대부분이네... 조사를 제거하기 위해 품사 태깅이 필요하다

# %%
doc_vectorizer.wv.most_similar('지진')
# Out:
# 2019-04-22 01:07:53,866 : INFO : precomputing L2-norms of word weight vectors
# [('발생', 0.5314663648605347),
#  ('규모', 0.5280847549438477),
#  ('포항', 0.49330219626426697),
#  ('여진', 0.45778101682662964),
#  ('진앙', 0.44243699312210083),
#  ('5.4', 0.4305582344532013),
#  ('강진', 0.4284333288669586),
#  ('진원', 0.4253193438053131),
#  ('5.8', 0.4214344918727875),
#  ('일어났다고', 0.4191873073577881)]

# %%
doc_vectorizer.wv.most_similar('홍수')
# Out:
# [('산사태', 0.4611701965332031),
#  ('폭우', 0.3905494213104248),
#  ('가뭄', 0.3431539535522461),
#  ('하류', 0.3286687135696411),
#  ('물난리', 0.3264271020889282),
#  ('내린', 0.3164568543434143),
#  ('대홍수', 0.311808705329895),
#  ('유역', 0.30570361018180847),
#  ('범람', 0.3046327829360962),
#  ('시스템', 0.30200839042663574)]

# %%
X_train = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_train_docs]
y_train = [doc.tags for doc in tagged_train_docs]

# %%
X_test = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_test_docs]
y_test = [doc.tags for doc in tagged_test_docs]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.cluster import KMeans

# %%
clf = KMeans(n_clusters=3, init='k-means++', random_state=1).fit(X_train)
clf
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %%
pred = clf.predict(X_test)

# %% [markdown]
# 1번 클러스터가 겨우 7개 분류가 잘 안되었다..

# %%
cnt = 0
for i in pred:
    if i == 2:
        cnt += 1

print(cnt)
# Out:
# 484

# %%
# 명사를 이용해서 clustering
tokens_title = [t for d in df_news['token_title'] for t in d]
tokens_contents = [t for d in df_news['token_contents'] for t in d]
tokens_keywords = [t for d in df_news['token_keywords'] for t in d]
